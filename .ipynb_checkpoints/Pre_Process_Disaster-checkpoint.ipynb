# %%
import os
import re
import csv
import pandas as pd
from sklearn.model_selection import train_test_split
import numpy as np
from tqdm import tqdm

# %%
def read_files(path):
    disaster_folders=os.listdir(path)
    
    data=[]
    uniq_labels={}
    
    for disaster_folder in disaster_folders:
        folder_path=os.path.join(path,disaster_folder)
        #print('folderPath',folder_path)
        labeled_csv_file=disaster_folder+'-tweets_labeled.csv'
        #print('labeled_csv_file',labeled_csv_file)
        csv_file_path=os.path.join(folder_path,labeled_csv_file)
        #print('csv_file_path',csv_file_path)
        with open(csv_file_path, newline='',encoding="utf8") as f:
            reader = csv.reader(f, delimiter=',')
            next(reader)
            for line in reader:
                text=line[1]
                label=line[3]
                if label=='Not labeled':
                    continue
                text=re.sub(r'http\S+', 'URL', text)
                if label not in uniq_labels:
                    uniq_labels[label]=label
                data.append({'text':text,'label':label})
    return data,uniq_labels

# %%
wf_data,wf_labels=read_files('./CrisisLexT26_Flood_Wildfire/wildfires')

# %%
flood_data,flood_labels=read_files('./CrisisLexT26_Flood_Wildfire/floods')

# %%
flood_labels,wf_labels
# Out:
# ({'Affected individuals': 'Affected individuals',
#   'Caution and advice': 'Caution and advice',
#   'Not applicable': 'Not applicable',
#   'Other Useful Information': 'Other Useful Information',
#   'Infrastructure and utilities': 'Infrastructure and utilities',
#   'Sympathy and support': 'Sympathy and support',
#   'Donations and volunteering': 'Donations and volunteering'},
#  {'Other Useful Information': 'Other Useful Information',
#   'Caution and advice': 'Caution and advice',
#   'Affected individuals': 'Affected individuals',
#   'Infrastructure and utilities': 'Infrastructure and utilities',
#   'Donations and volunteering': 'Donations and volunteering',
#   'Sympathy and support': 'Sympathy and support',
#   'Not applicable': 'Not applicable'})

# %%
len(flood_data),len(wf_data)
# Out:
# (2827, 1902)

# %%
flood_train ,flood_test = train_test_split(flood_data,test_size=0.25,random_state=11)

# %%
flood_train,flood_dev=train_test_split(flood_train,test_size=0.3,random_state=11)

# %%
def convert_to_file(listt,file_name):
    with open(file_name, 'w',encoding="utf-8") as f:
        for item in listt:
            data=item['text']+'\t'+item['label']
            f.write("%s\n" % data)

# %%
convert_to_file(flood_train,'./CrisisLexT26_Flood_Wildfire/floods_processed/train.txt')

# %%
convert_to_file(flood_dev,'./CrisisLexT26_Flood_Wildfire/floods_processed/dev.txt')

# %%
convert_to_file(flood_test,'./CrisisLexT26_Flood_Wildfire/floods_processed/test.txt')

# %%
wf_train ,wf_test = train_test_split(wf_data,test_size=0.25,random_state=11)

# %%
convert_to_file(wf_train,'./CrisisLexT26_Flood_Wildfire/wildfires_processed/train.txt')
convert_to_file(wf_test,'./CrisisLexT26_Flood_Wildfire/wildfires_processed/test.txt')

# %%
class DisasterProcessor:
    """Data loader for SNLI."""

    def __init__(self):
        self.label_map = {'Affected individuals': 0, 'Caution and advice': 1, 'Not applicable': 2,'Other Useful Information':3,'Infrastructure and utilities':4,'Sympathy and support':5,'Donations and volunteering':6}

    def valid_inputs(self, sentence1, label):
        return len(sentence1) > 0  and label in self.label_map

    def load_samples(self, path):
        samples = []
        with open(path, newline='',encoding='utf-8') as f:
            reader = csv.reader(f, delimiter='\t')
            next(reader)  # skip header
            desc = f'loading \'{path}\''
            for row in tqdm(reader, desc=desc):
                try:
                    sentence1 = row[0]
                    label = row[1]
                    if self.valid_inputs(sentence1, label):
                        label = self.label_map[label]
                        samples.append((sentence1, label))
                except:
                    pass
        return samples

# %%
processor=DisasterProcessor()
samples=processor.load_samples('./CrisisLexT26_Flood_Wildfire/wildfires_processed/train.txt')
# Out:
# loading './CrisisLexT26_Flood_Wildfire/wildfires_processed/train.txt': 763it [00:00, 7574.67it/s]
# ['RT @NationalPrayer: PRAYER ALERT: Remain in prayer for those fighting the #WaldoCanyonFire in Colorado Springs &amp; the 32,000+ people  ...', 'Sympathy and support']
# Sympathy and support
# ['RT @akcdoglovers: AKC CAR donates to help displaced animals in the Colorado wildfires URL', 'Donations and volunteering']
# Donations and volunteering
# ['RT @Sarakateee: RIP Colorado. Cause of death: fire.', 'Sympathy and support']
# Sympathy and support
# ['@PortDouglasSK yes some good rain would be very beneficial #nswfires', 'Other Useful Information']
# Other Useful Information
# ['Wildfires worsen in Colorado, 32,000 flee homes URL via @reuters', 'Affected individuals']
# Affected individuals
# ['RT @SheilaWalsh: Praying for divine intervention  and protection for all those affected by the fires in Colorado Springs. #waldocanyonfire', 'Sympathy and support']
# Sympathy and support
# ['RT @PadsCast: The fires are in Colorado Springs but there is a haze in the sky in Denver and you can smell the smoke because of the high ...', 'Other Useful Information']
# Other Useful Information
# ['RT @KimberleyL: :) RT @alexlee_24: @KimberleyL Two fires at Sydney Water and Sydney Aquatic Centre within a week. When did fire develop a s…', 'Not applicable']
# Not applicable
# ['Thinking of my bestie in colorado.. So many wildfires and not the latest one is close to her house and work. 😳💔', 'Sympathy and support']
# Sympathy and support
# ["RT @TheSwearyNews: Australia's on fucking fire again. Firefighters have blamed Harold Bishop for smoking in bed again.", 'Other Useful Information']
# Other Useful Information
# ['RT @james_willstrop: Whilst the floods cause havoc in Yorkshire, Colorado is burning. Wild fires are closing in on Estes Park! Desperate ...', 'Other Useful Information']
# Other Useful Information
# ['RT @MalloryOnTravel: Colorado Springs Fire Spreads to Tourist Areas: Pikes Peak, Rocky Mountain Park URL #travel #ttot', 'Infrastructure and utilities']
# Infrastructure and utilities
# ['Wildfires burn across Colorado, thousands evacuated: A spate of wildfires were burning across Colorado on Sunday... URL', 'Affected individuals']
# Affected individuals
# ['Hearing sad news the little prawn on the A43 at Crangan Bay (west of Catherine Hill Bay) has gone up in flames. #nswfires', 'Sympathy and support']
# Sympathy and support
# ['Amazing skies in Sydney at the moment with bush-fires nearby. URL', 'Other Useful Information']
# Other Useful Information
# ['RT @atmosphere: our thoughts go out to the people in colorado dealing with the wildfires.', 'Sympathy and support']
# Sympathy and support
# ["RT @brookejarvis: Colorado's on fire. Livestream of the fire prompting evacuation warnings in Boulder: URL #flagstafffi ...", 'Caution and advice']
# Caution and advice
# ["Plz Flw @RedneckRag: Colorado fire claims first #victim, ranks as state's most... URL  #ColoradoSprings #firstvictim", 'Affected individuals']
# Affected individuals
# ['Colorado fires sweep social media sites as readers look for info - Denver Post URL', 'Other Useful Information']
# Other Useful Information
# ['@BiancaGriffith #boulder #FlagstaffFire Esto es de Película Americana... URL', 'Other Useful Information']
# Other Useful Information
# ['RT @therealmalcolm: Yo Australia send my prayers hope people are safe from the fires @MKTOAustralia', 'Sympathy and support']
# Sympathy and support
# ['C10 Fire Safety Engineer Sydney URL  #ENGJobs', 'Other Useful Information']
# Other Useful Information
# ["Crisis Averted For Now In Australia's Fight Against Fires URL", 'Caution and advice']
# Caution and advice
# ['RT @RebelWilson: Thinking of everyone in Western Sydney who are being affected by the bush fires x be safe x', 'Sympathy and support']
# Sympathy and support
# ['Hope everyone in Greeley ok with wildfires in Colorado!', 'Sympathy and support']
# Sympathy and support
# ['#HighParkFire live briefing: Bill Hahnenberg, cmdr: The prognosis for the next day — a little better, but extreme weather conditions.', 'Other Useful Information']
# Other Useful Information
# ['Forest fires in Colorado! #awful URL', 'Other Useful Information']
# Other Useful Information
# ['RT @abcnews: NSW RFS Deputy Commissioner Rob Rogers describes Lithgow blaze as a monster fire. More: URL #NSWfires', 'Caution and advice']
# Caution and advice
# ['Colorado wildfires: Several fires explode across Front Range URL', 'Other Useful Information']
# Other Useful Information
# ["Massive Australia bush fire 'started by Defence Department' via @Telegraph URL", 'Other Useful Information']
# Other Useful Information
# ['Our Salvos Store in Springwood is open today offering support and practical assistance for bushfire affected locals #nswfires', 'Donations and volunteering']
# Donations and volunteering
# ['Top Story: Australia bush fire threat easing: Wildfires threaten the western suburbs of Austral... URL #ERMmedia @CNN', 'Infrastructure and utilities']
# Infrastructure and utilities
# ['RT @DanniiMinogue: NSW Australia: 59 bush fires. Hoping today luck is on our side for residents and fire fighters.🍀🐨', 'Sympathy and support']
# Sympathy and support
# ['We will try and keep our page up to date with fire updates around NSW as they come to hand', 'Caution and advice']
# Caution and advice
# ['Please join us in praying for the fire fighters who are bravely combating the bushfires across NSW. Our prayers... URL', 'Sympathy and support']
# Sympathy and support
# ['#nswfires #backburning operations  If you see an unattended #nswfire call Triple Zero, (000) immediately.  Do not call 000 to report smoke', 'Caution and advice']
# Caution and advice
# ['Forest / Wild Fire - Australia - Australia URL', 'Other Useful Information']
# Other Useful Information
# ["RT @BBCWorld: Did explosives from military exercise start massive bush fire in Australia's New South Wales? URL", 'Other Useful Information']
# Other Useful Information
# ['RT @ElaineByrne: The land burnt by #nswfires in Australia so far is bigger than the island of Ireland. #scaryshit', 'Other Useful Information']
# Other Useful Information
# ['RT @NSWRFS: Infrared image from #Lithgow fire - fire is spotting ahead, very intense activity. #NSWRFS #nswfires URL', 'Other Useful Information']
# Other Useful Information
# ['RT @ABCNews24: #BREAKING: NSW Police confirm pilot deceased in #Ulladulla #nswfires plane crash  #bushfires #ABCNews24', 'Affected individuals']
# Affected individuals
# ['RT @NSWRFS: Hall Rd Fire, Balmoral Village (Sthn Highlands) Fire has crossed railway line at Yanderra. Main Southern Railway clsed #nswfires', 'Caution and advice']
# Caution and advice
# ["RT @jrmontag: I usually love the smell of a campfire. Not so much when it's burning my town. #FlagstaffFire", 'Affected individuals']
# Affected individuals
# ['#fnre #nswbushfires Regular bushfire updates available through NSW RFS URL URL', 'Caution and advice']
# Caution and advice
# ["Front page shocker: A Colorado family learns - in a shocking way - that their home has been lost to fire. CNN's ... URL", 'Affected individuals']
# Affected individuals
# ['RT @pelagicpictures: Phil and Sue Dunlop search for valuables from the ashes of their home in Winmalee. @photosSMH #nswfires @smhnews URL', 'Affected individuals']
# Affected individuals
# ['#nswfires Nov01 16:00 70km ESE of Walcha /Oxley Hwy Kangaroo Flat Rd &amp; Racecourse Trail #outofcontrol #bushfire 150ha URL', 'Caution and advice']
# Caution and advice
# ['One of the Colorado wildfires has burned an area greater than Seattle URL via @KIRO7Seattle', 'Other Useful Information']
# Other Useful Information
# ['@twitterau during the #nswfires', 'Other Useful Information']
# Other Useful Information
# ["RT @Buzzoot: In solidarity with our brothers and sisters in Colorado, let's hope and pray for a quick end to the fires #PrayForRainInCo  ...", 'Sympathy and support']
# Sympathy and support
# ['RT @kariontour: Prayers going out too all the people in Colorado and the other states dealing with these deadly fires.', 'Sympathy and support']
# Sympathy and support
# ['Surging Colorado wildfires forcing tens of thousands to flee  URL', 'Affected individuals']
# Affected individuals
# ['RT @NationalPrayer: Heavenly Father, please be with the men and women fighting the #WaldoCanyonFire in the Colorado Springs area. Please ...', 'Sympathy and support']
# Sympathy and support
# ['Airstrip in Colorado Springs.', 'Not applicable']
# Not applicable
# ['RT @OwenNix: Sydney International Regatta Centre, doubling as a helicopter refueling station &amp; water source #nswfires URL', 'Other Useful Information']
# Other Useful Information
# ['For the latest on the massive #HighParkFire, follow @CBSDenver and get the details here: URL', 'Other Useful Information']
# Other Useful Information
# ['RT @NSWRFS: Thank you to the thousands of firefighters who have so bravely fought fires in difficult conds. #NSWRFS #nswfires URL', 'Sympathy and support']
# Sympathy and support
# ['Colorado Fires... Flying W - URL URL #FLYINGWRANCH #COLORADOFIRES', 'Other Useful Information']
# Other Useful Information
# ['@justinbieber  please bless my home Colorado springs is on fire :(', 'Sympathy and support']
# Sympathy and support
# ['RT @9NewsSyd: To put the #StateMineFire in perspective, this is how big it would be if it was burning in #Sydney. #nswfires URL', 'Other Useful Information']
# Other Useful Information
# ['RT @Nyx2701: “@9NewsSyd: #Springwood fire now threatening St Columba’s School. #nswfires URL #BlueMountains #BushFires', 'Caution and advice']
# Caution and advice
# ['#newbedon 6/28/2012 10:00:53 AM Colorado fire near Pikes Peak forces 11,000 from homes URL', 'Affected individuals']
# Affected individuals
# ['RT @nswfire: #nswfires status 11:45 URL Fire #advice #mountyorkroad 06:05 #linksviewroad  06:04 #hallroadfire 06:02 #how…', 'Other Useful Information']
# Other Useful Information
# ['RT @BULMKT: There is no Climate Change link to the #nswbushfires but there is a direct link between #Ecotardism and Adam Bandt #auspol', 'Other Useful Information']
# Other Useful Information
# ["its a shame Colorado couldn't have all this rain :( #wildfires", 'Other Useful Information']
# Other Useful Information
# ['Homes at risk from Colorado wildfire: Hundreds of families took refuge early Monday at a northern Colorado ... URL #CNN', 'Infrastructure and utilities']
# Infrastructure and utilities
# ["RT @HumaneSociety: we'll second that! RT @nalowry: Shout out to all local news agencies keeping people updated on the #highparkfire", 'Sympathy and support']
# Sympathy and support
# ['#nswpol #auspol #BlueMountains #Blackheath #MtVictoria #nswfires Heroes =@NSWRFS @FireRescueNSW  Pg2  newsletter URL', 'Other Useful Information']
# Other Useful Information
# ['RT @arschmitty: Praying for those who have been affected by the Colorado fires and hoping for the best 💜💜', 'Sympathy and support']
# Sympathy and support
# ['MY GOODNESS! My hometown of Colorado Springs seems to be in fire turmoil! What is going on down there!? If... URL', 'Sympathy and support']
# Sympathy and support
# ['RT @NSWRFS: Commissioner: Use today to prepare. Use tonight to check your Bush Fire Survival Plan. #nswfires #NSWRFS URL', 'Caution and advice']
# Caution and advice
# ["Beautiful morning in Sydney, sunshine and clear sky's - I hope this weather eases conditions for the fires across NSW.", 'Sympathy and support']
# Sympathy and support
# ['RT @reporterherald: #HighParkFire making push north over Red Feather Lakes Road. All of Glacier View, and more, evacuated. URL ...', 'Other Useful Information']
# Other Useful Information
# ['AUSTRALIA: Australia merges  blazes to prevent ‘mega-fire’: Firefighters battling unseasonable wildfires in so... URL', 'Other Useful Information']
# Other Useful Information
# ['RT @KerrinJeromin: Wow. terrible MT @wunderground @SeanSublette13  Terrifying fire in Colorado Springs, CO. Evacuations underway URL ...', 'Affected individuals']
# Affected individuals
# ['RT @Neinusername: Prime Minister Tony Abbott joins Davidson Rural Fire Brigade to fight NSW bushfires URL #auspol', 'Other Useful Information']
# Other Useful Information
# ['Man. You would swear Colorado was on fire.....', 'Not applicable']
# Not applicable
# ['RT @NSWRFS: Linksview Rd (Springwood): An Air crane has been deployed to assist crews. #nswfires #NSWRFS', 'Other Useful Information']
# Other Useful Information
# ['Unrelenting fires burn Australia: At least 57 bush fires are raging in eastern Australia, including 14 that ar... URL', 'Other Useful Information']
# Other Useful Information
# ['RT @NSWRFS: Hall Road Fire: An evacuation centre has been set up in Picton at the Brethren Church, Wonga Rd Picton. #nswfires #NSWRFS', 'Caution and advice']
# Caution and advice
# ['RT @cmyers75: “@cmyers75 “@Engadine_RFB “@BrentSGibson: Smoke seen  Williamtown Airport  #nswfires #Newcastle URL @ten…', 'Other Useful Information']
# Other Useful Information
# ['Smoke haze blankets #Illawarra URL via @illawarramerc #nswfires', 'Other Useful Information']
# Other Useful Information
# ["Australian fire crisis eases: Drop in temperature has slightly eased the bushfire crisis in Australia's New So... URL", 'Caution and advice']
# Caution and advice
# ["Top Story: Fears of 'mega-fire' forming: Australia firefighters are worried that two separate f... URL #ERMmedia @CNN", 'Other Useful Information']
# Other Useful Information
# ['RT @7NewsSydney: CHOPPERCAM: Emergency warning issued for area of Stockrington Road, west of the M1, heading towards Minmi #NSWfires URL', 'Caution and advice']
# Caution and advice
# ['Greg Hunt quotes Wikipedia to refute link between #NSWFires and #ClimateChange. I quote @mariekehardy: Are.  You.  F***ing.  Kidding.  Me.', 'Other Useful Information']
# Other Useful Information
# ['#Davis Colorado Springs Waldo Canyon wildfire forces thousands to flee flames URL', 'Affected individuals']
# Affected individuals
# ['RT @TimesCall: #HighParkfire 15% contained, but jumps the Poudre URL', 'Other Useful Information']
# Other Useful Information
# ["RT @bazarazzi: Government cut in aid 'heartless'. Appalling. Shame on you @MichaelKeenanMP. URL #nswfires", 'Sympathy and support']
# Sympathy and support
# ['RT @diversionary: Whoa. RT @workmanalice: Amazing photo from a friend in Katoomba on the road to Blackheath. #nswfires URL', 'Infrastructure and utilities']
# Infrastructure and utilities
# ['Be safe my south boulder friends. This one breaks my heart :( #flagstafffire #tooclosetohome URL', 'Sympathy and support']
# Sympathy and support
# ['RT @SkratchLabs: Check out @cofiresale and bid on a year supply of @SkratchLabs to help raise money for the Colorado Fires.  Please RT!', 'Donations and volunteering']
# Donations and volunteering
# ["RT @photogramel: The NSW Fire &amp; Rescue Service was set a $11M savings target by the O'Farrell government. URL", 'Other Useful Information']
# Other Useful Information
# ['RT @mattdoran22: Reports a chopper has crashed fighting fires near Ulladulla #nswfires #eyewitnessnews @channeltennews', 'Affected individuals']
# Affected individuals
# ["NSW RFS: Hall Rd fire likely to be 'Contained' by this afternoon. Thank you to all emergency services personnel for their hard work!", 'Sympathy and support']
# Sympathy and support
# ['RT @channeltennews: If you need to stay up to date with bushfire conditions – make sure you also follow @NSWRFS on twitter. #SydneyFires #n…', 'Caution and advice']
# Caution and advice
# ['Latest on the #nswfires here URL', 'Other Useful Information']
# Other Useful Information
# ['We are sending our positive thoughts to all who are affected by the fires in our beloved home state of Colorado.', 'Sympathy and support']
# Sympathy and support
# ['RT @ABCNews24: Shane Fitzsimmons: There are more than 60 fires across NSW, 15 of those remain uncontained #nswfires #bushfires', 'Caution and advice']
# Caution and advice
# ["I've got family in Colorado Springs, so I've been keeping a close eye on the wildfires through the #nws website.  URL", 'Affected individuals']
# Affected individuals
# ["RT @abcnews: #Breaking: A state of emergency is declared in NSW by Premier Barry O'Farrell. Live: URL #NSWfires", 'Caution and advice']
# Caution and advice
# ["#AusPol @TonyAbbottMHR quotes Dorothea Mackellar to explain Australia's ability to cope with fire: URL", 'Other Useful Information']
# Other Useful Information
# ["What a week it's been!  #highparkfire you better behave today.  URL", 'Sympathy and support']
# Sympathy and support
# ['RT @gcnelson: A weary firefighter catches a well earned rest as the worst appears over. @abcnews #NSWfires URL', 'Affected individuals']
# Affected individuals
# ['Our hearts go out to all those affected by the terrible fires. Stay safe. NSW Rural Fire Service - Bush Fire... URL', 'Sympathy and support']
# Sympathy and support
# ['Being able to see the forest fires in New Mexico/Colorado from our hotel #sketchy', 'Affected individuals']
# Affected individuals
# ['Saying that, though, my thoughts go out to those who are affected by this horrible natural disaster. #nswbushfires', 'Sympathy and support']
# Sympathy and support
# ['RT @KDVR: Pre-evacuation notice for the city of #Boulder URL #flagstafffire', 'Caution and advice']
# Caution and advice
# ['RT @RMACCFireinfo: Tanker update: 6 pm, 37 drops, 58,557 gals retardant on #HighParkFire from #JeffcoAirTankerBase.... URL', 'Other Useful Information']
# Other Useful Information
# ["Fires in Sydney's Blue Mountains have destroyed nearly 200 homes. #nswfires URL", 'Infrastructure and utilities']
# Infrastructure and utilities
# ['New forest fire just broke out in Boulder! 14 forest fires in CO right now! Praying my heart out!', 'Sympathy and support']
# Sympathy and support
# ['URL #boulderfire', 'Other Useful Information']
# Other Useful Information
# ['RT @Meagan9News: Concern today for #highparkfire: Explosive weather conditions because of heat, high winds and low humidity.', 'Other Useful Information']
# Other Useful Information
# ['@9NEWS: Incident command: NE &amp; SE corners, S flank of #HighParkFire are hot. East flank, which is closest to Ft Collins is calm', 'Other Useful Information']
# Other Useful Information
# ['RT @HaydosTweets: Final shout out! Thoughts and prayers tonight for the brave folk of #nswfires #GodBless can I request my followers to re …', 'Sympathy and support']
# Sympathy and support
# ['RT @Reuters: Monster Colorado wildfire rages; Obama plans visit URL', 'Other Useful Information']
# Other Useful Information
# ['RT @ksbw: Hundreds of homes destroyed in raging Colorado fire: Colorado Springs officials said Thursday that hundreds of homes... URL ...', 'Infrastructure and utilities']
# Infrastructure and utilities
# ['RT @NSWRFS: Watch and Act - Hall Road (Southern Highlands / Wollondilly).  URL Picton Rd now open #nswrfs #nswfires', 'Caution and advice']
# Caution and advice
# ["Damage Assessment teams for #HighParkFire being assembled to determine what' structures have been burned, damaged or untouched.", 'Infrastructure and utilities']
# Infrastructure and utilities
# ['News Update Furious Wildfire in Colorado Leaves Destruction in Its Wake URL', 'Infrastructure and utilities']
# Infrastructure and utilities
# ["#highparkfire It's a slow progress, but we need to have favorable weather and we've had that the last couple of days.", 'Other Useful Information']
# Other Useful Information
# ['Smell of Ash in Sydney  is a reminder of how close we are to the fires . My family home burnt down in 1980 so understand the trauma#fires', 'Affected individuals']
# Affected individuals
# ['RT @PhotoWil: The only thing I can do to help Colorado is wait til all the fires are out, then spend my tourist $ there asap. Hope you w ...', 'Sympathy and support']
# Sympathy and support
# ["Video: AP  - AP Top Stories: Here's the latest news for Tuesday, June 26: Colorado fires rage in hot, dry condit... URL", 'Other Useful Information']
# Other Useful Information
# ['RT @bouldercounty: Material donations are NOT needed for the #FlagstaffFire at this time. Financial support is the best way to help. Inf ...', 'Donations and volunteering']
# Donations and volunteering
# ['News by BBC Australia bush fires set to worsen: Australian firefighters warn that the return of hot weather an...  URL', 'Caution and advice']
# Caution and advice
# ['RT @thewest_com_au: It will be a miracle if no lives are lost to NSW bushfires: Premier. [with videos] #NSWfires URL', 'Other Useful Information']
# Other Useful Information
# ['@ChilledChaos If you have time could you do a shout-out for the Creatures charity stream for the Colorado Wildfires? URL', 'Donations and volunteering']
# Donations and volunteering
# ['Photo: Colorado wildfire near Air Force’s Falcon Stadium URL', 'Other Useful Information']
# Other Useful Information
# ['RT @heldavidson: Southern Highlands bushfire upgraded to emergency warning. @guardianaus #nswfires live blog URL', 'Caution and advice']
# Caution and advice
# ['RT @7NewsSydney: GALLERY: #NSW bushfire devastation in pictures: URL #nswfires', 'Other Useful Information']
# Other Useful Information
# ["RT @AP: AP VIDEO: Colorado wildfires double in size overnight, 'not remotely close to being contained': URL -EF", 'Other Useful Information']
# Other Useful Information
# ['FOLLOW AND RETWEET FOR RAIN FOR FRONT RANGE COLORADO AND THE SPRINGS PLEASE - GOD BLESS AND THANKS! -... URL', 'Sympathy and support']
# Sympathy and support
# ['Firies to link two Blue Mountains Fires: A desperate backburning operation in the NSW Blue Mountains is underway... URL', 'Other Useful Information']
# Other Useful Information
# ['There is a growing fire near Norwest Hospital, NSW.  Fire brigade is in attendance.', 'Caution and advice']
# Caution and advice
# ['Australia weather increases threat of fires: Fifteen fires continue to burn out of control in  New South Wales... URL', 'Infrastructure and utilities']
# Infrastructure and utilities
# ['PRAYING.. RT @leighramsey: Colorado Fire: Worst in 32 yrs. Perfect storm apparently. 32 thousand being evacuated URL', 'Affected individuals']
# Affected individuals
# ['RT @DrOz: My prayers go out to everyone in the Colorado Springs area. Stay safe!', 'Sympathy and support']
# Sympathy and support
# ['RT @dbouwman: Pretty smoke free day Fort Collins, but the smoke is settling in now... closing windows! #highparkfire', 'Affected individuals']
# Affected individuals
# ['#NSWFIRES  #MEDOWIE #NSW  Residents in this areas are advised to #shelter_in_place as the #firefront approaches URL', 'Caution and advice']
# Caution and advice
# ['RT @stormchaser4850: Developing: Around 32,000 evacuated in the Colorado Springs, CO area due to destructive wildfire via press conference', 'Affected individuals']
# Affected individuals
# ['RT @NSWRFS: If you find an injured native animal, call WIRES 13000WIRES or DPI for livestock.  URL @WIRES_NSW #nswfires', 'Not applicable']
# Not applicable
# ['RT @denvernews: Denver News: Colorado to sizzle with record heat Monday, fire danger is high URL', 'Other Useful Information']
# Other Useful Information
# ['RT @AlexChesser: Three big days ahead for firefighters. Help us by planning ahead &amp; knowing what you will do if threatend by #nswfires URL', 'Caution and advice']
# Caution and advice
# ["The copter is on the way to the #HighParkFire. We'll be airing it live throughout our coverage. You can also follow @CodyCrouch for pics.", 'Other Useful Information']
# Other Useful Information
# ['@d4_aspen Hey Asp! I have friends who live in Colorado Springs,CO and they are evacuating the city becuz of wild fires. Can you please (c)', 'Affected individuals']
# Affected individuals
# ['Think and Pray for Colorado Springs Residents- FIRE- it could happen anywhere-Be Prepared!', 'Sympathy and support']
# Sympathy and support
# ['@RADickey43 Please RT. Colorado Springs is suffering badly from a large forest fire. Text the word REDCROSS for a $10 donation. Thank You', 'Donations and volunteering']
# Donations and volunteering
# ['Colorado wildfires: Real-time social media response map URL via @denverpost', 'Other Useful Information']
# Other Useful Information
# ['Photo | The @RBB_net show a sign of respect to the victims of the NSW fires. #GoWanderers #aleague URL', 'Sympathy and support']
# Sympathy and support
# ["Despite the weekend's cooler temperatures, crews are conducting critical backburning operations. There are still 53 fires burning. #nswfires", 'Other Useful Information']
# Other Useful Information
# ['RT @ch150ch: Abbott (who claims exps for runs, swims &amp; bike rides) changes rules so less people to get #nswfires disaster payment URL', 'Other Useful Information']
# Other Useful Information
# ['RAIN ALREADY #COLORADO.  It looks like Armageddon over there.  #flagstafffire', 'Sympathy and support']
# Sympathy and support
# ["At least 57 bush fires are raging in eastern Australia, including 14 that aren't contained, officials said. URL", 'Other Useful Information']
# Other Useful Information
# ['@THEKINGColucci Australia Fires: Military Investigates Blaze: The military reveals it was conducting an explosives training...  @deadmau5', 'Other Useful Information']
# Other Useful Information
# ["RT @triplejHack: We're talking about whether it's too early to blame climate change for the #nswfires. Are you worried these are happening …", 'Other Useful Information']
# Other Useful Information
# ['RT @FeedingAmerica: The outpouring of support for @careandsharefb is awesome! They are helping the Colorado fire evacuees URL ...', 'Donations and volunteering']
# Donations and volunteering
# ['RT @bigbooty_JUDYYY: Prayers go out to everyone affected by these wildfires in Colorado! The Lord is the ultimate protector, trust in Him.', 'Sympathy and support']
# Sympathy and support
# ['RT @treisiroon: Military live ordinance exercises was cause of one of the fires raging in #Australia URL v @jaraparilla', 'Other Useful Information']
# Other Useful Information
# ["#bushfires 'Significant' number of homes lost as 100 wildfires rage across Australian state (from @AP) #nswfires URL", 'Infrastructure and utilities']
# Infrastructure and utilities
# ["RT @DanMacPherson: Just up to speed on today's horrific fires. Thoughts with all involved. Heartbreaking. Just heartbreaking.  #nswfires", 'Sympathy and support']
# Sympathy and support
# ["I've figured out why Colorado is on fire. Al Qaeda hacked the CIA weather control satellites using a virus that was implanted in Osamas DNA", 'Other Useful Information']
# Other Useful Information
# ['@csgazette reporting that Colorado Springs is under another red flag warning today. #WaldoCanyonFire', 'Caution and advice']
# Caution and advice
# ['Please keep Colorado and Florida in your prayers. Wildfires and flooding...', 'Sympathy and support']
# Sympathy and support
# ['RT @SalArmyEDS: Help #SalvationArmy assist disaster survivors - T.S. #Debby URL &amp; Colorado #wildfires URL ...', 'Donations and volunteering']
# Donations and volunteering
# ['Federal firefighters go uninsured: As brutal wildfires spread in Colorado, federal fighters, along with state an... URL', 'Other Useful Information']
# Other Useful Information
# ['RT @850KOA: Devasting update from #HighParkFire.  112 homes lost.  More likely to be counted in the coming days.', 'Infrastructure and utilities']
# Infrastructure and utilities
# ['RT @cnnbrk: Officials: At least 57 bush fires rage in Australia; state of emergency declared URL', 'Caution and advice']
# Caution and advice
# ["RT @SignaramaFC: Mulberry &amp; Lemay vie west 30 min ago. Can hardly believe it's actually 15 miles away!  #highparkfire URL ...", 'Other Useful Information']
# Other Useful Information
# ["New game... Drink everytime you see a Sydney Bushfire photo on your Instagram feed... GO!.. OK I'll call you and ambulance now :-( #nswfires", 'Other Useful Information']
# Other Useful Information
# ['RT @abcnews: The UN says the NSW fires are an example of the doom the world may face without action on climate change. URL', 'Other Useful Information']
# Other Useful Information
# ['RT @KyleClark: RT @northfortynews: High winds at #HighParkFire sent flames 300-400 feet in the air near the top of East White Pine Mtn h ...', 'Other Useful Information']
# Other Useful Information
# ['RT @BBCWorld: Australia bush fires set to worsen URL', 'Other Useful Information']
# Other Useful Information
# ['High Park Fire: Kansas &amp;amp; Nebraska National Guards Support Colorado URL via @youtube [Like it? URL ]', 'Donations and volunteering']
# Donations and volunteering
# ['Colorado Spring wildfire URL', 'Other Useful Information']
# Other Useful Information
# ['Pic: #CoFire: Helicopter drops water on #WaldoCanyonFire #Wildfire USAF Academy Colorado Springs, Colo. URL', 'Other Useful Information']
# Other Useful Information
# ["RT @onweeronline: Prachtige foto's van de National Guard in strijd tegen #HighParkFire #wildfire #firefighting #NationalGuard #Colorado  ...", 'Other Useful Information']
# Other Useful Information
# ["@BasedBieberLife Australia fire threat 'averted': Australian fire officials say the threat to the Blue Mountains west of Sy...  @deadmau5", 'Caution and advice']
# Caution and advice
# ['RT @LogansLaundry: At a shoot right near Sydney fires!! There is ash embers flying into my eyes!!', 'Other Useful Information']
# Other Useful Information
# ["RT @australian: Fears grow blazes will form 'mega-fire': NSW fire chiefs are growing increasingly worried major bushfires in t... URL", 'Caution and advice']
# Caution and advice
# ['#news #update Raging Colorado wildfire prompts FBI investigation - uReport: Colorado wildfire:  URL #follow', 'Other Useful Information']
# Other Useful Information
# ['Firefighters search door-to-door for bodies in Colorado wildfire - Fox News: ABC NewsFirefighters search door-to... URL', 'Affected individuals']
# Affected individuals
# ['#Sydney #fire please be over right now!! URL', 'Other Useful Information']
# Other Useful Information
# ['RT @phochemrd: @msnbc there is a firestorm in Colorado  springs. #waldocanyonfire are your covering this? @CNN is still several hours be ...', 'Other Useful Information']
# Other Useful Information
# ['RT @convectivetweet: Massive Wildfire near Colorado Springs. URL', 'Other Useful Information']
# Other Useful Information
# ['Most destructive ever Colorado wildfire burns 181 homes - U.S. News URL #COLORADOWILDFIRES', 'Infrastructure and utilities']
# Infrastructure and utilities
# ['RT @EmMastronardi: If you want to put the Lithgow fire in perspective, here is the size outlaid on a map of Sydney. #nswfires URL', 'Other Useful Information']
# Other Useful Information
# ["RT @JezFernandezABC: It's just terrific seeing Auslan translators as a normal component of emergency mgmt procedures. Very smart. #nswfires.", 'Other Useful Information']
# Other Useful Information
# ['RT @Denver_Broncos: #Broncos FB @Chrisgronkowski poses with a firefighter in Colorado Springs URL', 'Other Useful Information']
# Other Useful Information
# ['RT @newscomauHQ: FIRE UPDATE: Families told to be ready to run as a massive 300km wall of fire sweeps through Blue Mtns. #nswfires | URL', 'Caution and advice']
# Caution and advice
# ['RT @katelynburkhart: praying for the people, animals and entire communities affected by this #highparkfire. truly unreal.', 'Sympathy and support']
# Sympathy and support
# ['State Mine: Photo from Mountain Lagoon Rd taken by Hawkesbury Gazette URL #nswfires #NSWRFS', 'Other Useful Information']
# Other Useful Information
# ["Sitting here inhaling the #nswbushfires smoke. Can't imagine what ppl are going through. Buy an ad this week &amp; we'll donate to the victims.", 'Donations and volunteering']
# Donations and volunteering
# ['YOU GUYS COLORADO SPRINGS IS TRENDING. prayers going out to the fire and all the girls i know living there.&lt;33', 'Sympathy and support']
# Sympathy and support
# ['RT @NSWRFS: State Mine Fire: Fire has been downgraded to Watch &amp; Act #NSWRFS #nswfires', 'Caution and advice']
# Caution and advice
# ['President Obama to tour #WaldoCanyonfire Friday URL via @denverpost #cofire #potus', 'Other Useful Information']
# Other Useful Information
# ['Flames Encroach on Colorado Springs: Some of our viewers in Colorado Springs sent us their pictures of the fire ... URL', 'Affected individuals']
# Affected individuals
# ['#Wildfire @ABC: Record Colorado Wildfire to Be Probed as Possible Arson URL', 'Other Useful Information']
# Other Useful Information
# ['RT @9NEWS: BREAKING: new #COFire near Platteville, Weld Co CR32 &amp; CR35, there are evacuations PIC from Allyson Kulinski  URL ...', 'Affected individuals']
# Affected individuals
# ["RT @Magdalena_Roze: This ISN'T rain on SYDNEY RADAR! Its a massive smoke plume from LITHGO FIRES travelling to coast by NW winds! #fires ht…", 'Other Useful Information']
# Other Useful Information
# ["RT @TheEllenShow: Australia's 1 of the most beautiful places I've ever been to. Images of the fires are heartbreaking. Sending all my love …", 'Sympathy and support']
# Sympathy and support
# ['RT @StyleEngine: Colorado Springs is burning, this gives you an idea of how bad the wild fire is... URL', 'Other Useful Information']
# Other Useful Information
# ["Visits home allowed in areas burned by Colorado fires: People who fled the most destructive fire in Colorado's h... URL", 'Other Useful Information']
# Other Useful Information
# ['RT @newscomauHQ: Investigations by NSW RFS fire investigators have determined the State Mine Fire... was started as a result of live ordna…', 'Other Useful Information']
# Other Useful Information
# ['Thousands evacuated as Colorado wildfire nears URL', 'Affected individuals']
# Affected individuals
# ['Ciggie butt may have started Sydney fire:      A cigarette butt is suspected of causing a grass fire at Sydney... URL', 'Other Useful Information']
# Other Useful Information
# ['Colorado wildfire: Last Chance, residents stand tall after huge wildfire URL', 'Affected individuals']
# Affected individuals
# ['Colorado wildfire forces 11,000 people to leave their homes \\\\ Guardian \\\\ URL', 'Affected individuals']
# Affected individuals
# ["@chipmaclasco you're a better man than me. I hope Tim Thomas loses everything in the Colorado wild fires #ShouldveStayedInBoston", 'Other Useful Information']
# Other Useful Information
# ['To all the Emergency crews in Colorado Springs. Be Brave and Godspeed! It is hell there right now. #firebrea URL', 'Sympathy and support']
# Sympathy and support
# ['My thoughts and prayers are with the People and the Fire Fighters in Sydney...', 'Sympathy and support']
# Sympathy and support
# ['RT @NationalPrayer: Heavenly Father, please be with the men and women fighting the #WaldoCanyonFire in the Colorado Springs area. Please ...', 'Sympathy and support']
# Sympathy and support
# ['1 dead as Colorado fire destroys over 300 homes- uReport: Colorado wildfire URL #IHateTimWaterman', 'Affected individuals']
# Affected individuals
# ['“@EmmaK46: Thinking of everyone helping to fight fires in Australia. Every day heros... 😢 URL #amazing #heros 🐨', 'Sympathy and support']
# Sympathy and support
# ['Flick on TEN now RT @DaniIsdale: @SouthwoodEllie coming back live with update before the end of the show @TenLateNews #SydneyFires', 'Not applicable']
# Not applicable
# ['346 homes destroyed in Colorado and 1 person found dead..my thoughts and prays are with the people of Colorado Springs during this time!!!', 'Sympathy and support']
# Sympathy and support
# ["#Climate change and fires in Australia: why it won't be a smooth ride URL #nswfires", 'Other Useful Information']
# Other Useful Information
# ["the #wildfires in Colorado are out of control! They are across the highway from my friend's apartment... URL", 'Affected individuals']
# Affected individuals
# ['Colorado fire displaces hundreds; 1 person missing: Firefighters in Colorado and New Mexico are battling wind-fu... URL', 'Affected individuals']
# Affected individuals
# ['RT @9NewsSyd: UPDATE: Watch &amp; Act alerts in place for #MtVictoria &amp; #Balmoral in Southern Highlands. @thetodayshow #nswfires URL', 'Caution and advice']
# Caution and advice
# ['RT @larryemdur: Dear pathetic arseholes  looting houses in NSW fire zones .. You are disgusting pieces of shit !!!!', 'Sympathy and support']
# Sympathy and support
# ['RT @9NEWS: #HIGHPARKFIRE now 45% containment, has burned 55,050 acres.  #9NEWS', 'Infrastructure and utilities']
# Infrastructure and utilities
# ['RT @FireBlogger: Peregrin/Blodgett neighborhood Colorado Springs, no struct. protection. Not enough resources on scene #WaldoFire URL ...', 'Other Useful Information']
# Other Useful Information
# ['RT @NHLPA: RT @ryanobyrne84: My thoughts are with everyone in Colorado and hoping the fires come to an end. #PrayForColorado', 'Sympathy and support']
# Sympathy and support
# ["@SixlitreHSV tomorrow's conditions predict the worst in nsw history for these fires and there's nothing we can do to help #frustrating", 'Sympathy and support']
# Sympathy and support
# ['Hey fam. Please pray for the residents of Colorado. With the winds, the fires are spreading rapidly. We are praying for you, Colorado!!!!', 'Sympathy and support']
# Sympathy and support
# ['RT @NSWRFS: A picture tells 1000 words: Photos from the fire front and/or smoke plumes help us fight the fires email photos@rfs.nsw.gov.au …', 'Affected individuals']
# Affected individuals
# ['Sky News - Colorado Wildfires: Blaze Claims First Life URL', 'Affected individuals']
# Affected individuals
# ['Thanks for the RTs @mayread3 Maria, appreciate your support. Needs ongoing. #HighParkFire #smday URL', 'Sympathy and support']
# Sympathy and support
# ['Large wildfire in northern Colorado prompts evacuations - Fox News: CBS NewsLarge wildfire in northern Colorado ... URL', 'Caution and advice']
# Caution and advice
# ["RT @nprnews: Good News: 'Great Progress' Reported In Fighting Colorado Springs Fire URL", 'Other Useful Information']
# Other Useful Information
# ['Colorado wildfires their worst in a decade URL', 'Other Useful Information']
# Other Useful Information
# ['Thoughts going out to everyone affected by #nswfires', 'Sympathy and support']
# Sympathy and support
# ['RT @NSWRFS: Likely to be heavy smoke across Sydney and much of the state Dont call 000 just for smoke only for unattended fires   URL', 'Caution and advice']
# Caution and advice
# ['RT+@KCCINews:   #Australia bush #fires blaze in New South Wales URL', 'Other Useful Information']
# Other Useful Information
# ['RT @fosterthepeople: “@fosterthefuture: fans helped us raise $15,830 for the Colorado Wildfire Relief Fund last night at Red Rocks. Spee ...', 'Donations and volunteering']
# Donations and volunteering
# ['Colorado, New Mexico forest fire crews gain ground: (Reuters) - Fire crews battling flames roaring through natio... URL', 'Other Useful Information']
# Other Useful Information
# ['“It’s ugly,” he said.  #HighParkFire #WaldoCanyonFire #COfire URL', 'Other Useful Information']
# Other Useful Information
# ['Great interview, @riaglo!!! How Social Media Is Helping Colorado Wildfire Relief  URL via @mashable #COwx', 'Other Useful Information']
# Other Useful Information
# ['RT @NSWRFS: Watch &amp; Act - Linksview Rd, Springwood Four local schools closed tomorrow URL #nswfires #nswrfs', 'Infrastructure and utilities']
# Infrastructure and utilities
# ['#HighParkFire has burned about 73 square miles. Washington, DC measures 68 square miles. NASA photo t.co', 'Infrastructure and utilities']
# Infrastructure and utilities
# ['Sydney fires will be known as the #greenoctoberfires thanks to @AdamBandt and fundamentalist party. #pmlive', 'Other Useful Information']
# Other Useful Information
# ["RT @truuebluu: Don't forget our mates in the bushfires. #NSWfires URL", 'Sympathy and support']
# Sympathy and support
# ['Praying hard. RT@DenverWestword: High Park fire update: 83K-plus acres, 248 homes confirmed destroyed  #highparkfire URL', 'Infrastructure and utilities']
# Infrastructure and utilities
# ['RT @cnnbrk: Colorado governor lifts statewide fire ban. URL', 'Other Useful Information']
# Other Useful Information
# ['RT @nswdpi: #nswfires: horses can be taken directly to #Penrith Paceway or the #Hawkesbury Showground @702sydney @NSWRFS', 'Caution and advice']
# Caution and advice
# ['RT @dailytelegraph: Follow @NSWRFS - they are live tweeting all information they have immediately. @nswfires #bushfires #sydneyfires Blue M…', 'Caution and advice']
# Caution and advice
# ['RT @rpy: ABC 702 reporting lit embers are falling on the water at Bondi #nswfires', 'Caution and advice']
# Caution and advice
# ['RT @TmCentralCoast: “@NSWRFS: Important information about donations URL  #nswfires”', 'Donations and volunteering']
# Donations and volunteering
# ['RT @AllianzStadium: DONATE YOUR SPARE CHANGE to the @SALVOS. Collection buckets located at entry gates tonight #SydneyDerby #sydneyfires #l…', 'Donations and volunteering']
# Donations and volunteering
# ['RT @nswpolice: Fires, floods and park closures: See latest updates and alerts for national parks across NSW - URL', 'Infrastructure and utilities']
# Infrastructure and utilities
# ['RT @DenverChannel: @Bri_Smith91 Sadly rain, well the lightning that came with it, started the Boulder fire yesterday.', 'Other Useful Information']
# Other Useful Information
# ["Colorado fire claims first victim, ranks as state's most destructive: COLORADO SPRINGS, Colo. (Reuters) - A fier... URL", 'Affected individuals']
# Affected individuals
# ['Colorado to double wildfire crews: Officials plan to more than double the amount of fire engines battling the ra... URL', 'Other Useful Information']
# Other Useful Information
# ['#Australia #Wildfires: Nearly 100 Fires Rage Across New South Wales URL  #climate', 'Caution and advice']
# Caution and advice
# ['My thoughts &amp; prayers go out to the victims and lost of loved ones to the wildfires in colorado. i wanna do a fundraiser.', 'Sympathy and support']
# Sympathy and support
# ['RT @VaSarver: Yall complaining about no power and ac and the people in Colorado losing their HOMES and LIVES to fires. #bethankful', 'Sympathy and support']
# Sympathy and support
# ['RT @dailycamera: Dispatchers: Heavy air tanker now en route to #BisonFire  west of #boulder', 'Donations and volunteering']
# Donations and volunteering
# ['@kumitaguchi if you could use #nswfires that would be great', 'Other Useful Information']
# Other Useful Information
# ['RT @BBCWorld: Video: Aerial views show extent of #nswfires, amid fears three blazes could merge URL', 'Affected individuals']
# Affected individuals
# ['This is crazy #highparkfire URL', 'Other Useful Information']
# Other Useful Information
# ['RT @Ai_Live: #Bushfire information for those who are #Deaf or hard of hearing. URL #nswbushfires', 'Other Useful Information']
# Other Useful Information
# ['Lithgow bushfires #nswfires URL', 'Other Useful Information']
# Other Useful Information
# ["RT @geoffstults: This is the Waldo Canyon fire in Colorado Springs and surrounding areas. Where my family lives. It's insane. URL ...", 'Other Useful Information']
# Other Useful Information
# ['Record hot year causes fire emergency in Australia: The hottest 12 months on record in Australia have resulted... URL', 'Other Useful Information']
# Other Useful Information
# ['Colorado wildfire hops road: Firefighters Thursday made progress against a massive wildfire 15 miles west of For... URL', 'Other Useful Information']
# Other Useful Information
# ['@9NewsAdel feeling for the people of NSW. I have friends who have lost their home in this bush fires.', 'Sympathy and support']
# Sympathy and support
# ["Here's a pic of Colorado and the fires from space. URL", 'Other Useful Information']
# Other Useful Information
# ['RFS Commissioner says he still has concerns for #Springwood blaze  #nswfires', 'Caution and advice']
# Caution and advice
# ['“@smh: A blood red sky over Tom Uglys Bridge in south Sydney. Photo: Chris Lane. #nswfires URL - RT - Amazing!', 'Other Useful Information']
# Other Useful Information
# ['RT @LarimerCounty: Map of #HighParkFire as of 00:20 this morning. URL', 'Other Useful Information']
# Other Useful Information
# ["RT @A_DarlingMP: Alex Salmond wants us to leave the Union. What assurances can he give that we won't end up on fire like Australia? URL", 'Not applicable']
# Not applicable
# ['Great one here: Colorado wildfire roars to 73 square miles - Fox News  [a link in my bio]', 'Other Useful Information']
# Other Useful Information
# ['Colorado fires sweep social media sites as readers look for info - Denver Post URL', 'Other Useful Information']
# Other Useful Information
# ['RT @adam_wilkinson: Sydney fire 300km wide. Worst fire conditions in 40yrs. Katoomba preparing to evacuate &amp; state of emergency declared. S…', 'Caution and advice']
# Caution and advice
# ["RT @mashable: Mashable's @zoebfox takes a look at how social media is helping Colorado wildfire relief URL", 'Other Useful Information']
# Other Useful Information
# ['Sun through the smoke. #nofilter #sydneyfires URL', 'Other Useful Information']
# Other Useful Information
# ['RT @cnni: 32,000 evaculated from Colorado wildfires URL', 'Affected individuals']
# Affected individuals
# ["RT @p_hannam: Is this a sign that Abbott government will follow O'Farrell and outsource #climate science? URL #nswfires …", 'Other Useful Information']
# Other Useful Information
# ['RT @weirdaustralia: Last October near Blackheath in the Blue Mountains #nswfires URL', 'Caution and advice']
# Caution and advice
# ["We've reached the point of our trip to Colorado that we should be able to see mountains but because of the wildfires all we see is a haze.", 'Affected individuals']
# Affected individuals
# ["Colorado fire 'smacks you in the face' - Neighborhoods in Colorado Springs, Colorado, are evacuated as the Waldo Can... URL", 'Affected individuals']
# Affected individuals
# ['Aftermath of a Forest Fire URL via @wordpressdotcom -- 16 #photos #wildfire #environment', 'Other Useful Information']
# Other Useful Information
# ['Where the fuck is @TonyAbbottMHR &amp; @GregHuntMP today to stand among these burnt homes &amp; spout climate denial bullshit. #nswfires', 'Other Useful Information']
# Other Useful Information
# ['RT @AnthonyClarkAU: Incredibly proud of the #NSWRFS public info team over the last few days. In the age of technology and immediate info, t…', 'Other Useful Information']
# Other Useful Information
# ['RT @cnnbrk: Officials: At least 57 bush fires rage in Australia; state of emergency declared URL', 'Caution and advice']
# Caution and advice
# ["#nswfires People queuing for over an hour at Blaxland tip. C'mon Blue Mtns council open up the tip!", 'Affected individuals']
# Affected individuals
# ['Hang in there New South Wales. The rest of Australia is thinking of you. Stay safe. #nswbushfires', 'Sympathy and support']
# Sympathy and support
# ["Key points from this morning's 7am briefing at NSW Rural Fire Service HQ - * 56 bush and grass fires, 12... URL", 'Other Useful Information']
# Other Useful Information
# ['US: All three network evening newscasts leading tonight with the rampage of that #wildfire in #Colorado', 'Other Useful Information']
# Other Useful Information
# ['Sydney CBD skyline, shrouded in smoke, blue skies reflected in the glass of the buildings. #nswfires #bushfires URL', 'Other Useful Information']
# Other Useful Information
# ['RT @smh: Sydney Water warns that water pressure may be low in some areas due to extremely heavy demand for fire fighting. URL', 'Caution and advice']
# Caution and advice
# ['RT @NSWRFS: #NSWRFS crews are responding to a fire reported in the Salt Ash area (Port Stephens). #nswfires', 'Other Useful Information']
# Other Useful Information
# ['RT @NSWRFS: Status of evacuation centres: URL #NSWRFS #nswfires', 'Caution and advice']
# Caution and advice
# ['RT @Lisa_Wilkinson: To all the men &amp; women out there today fighting the good fight in the worsening #nswbushfires thank you. Your bravery &amp;…', 'Sympathy and support']
# Sympathy and support
# ['RT @diversionary: Another bushfire sunset in Sydney… thoughts go out to everyone affected by or fighting the fires', 'Sympathy and support']
# Sympathy and support
# ['RT @denverpost: #HighParkFire, at 14,000 acres (22 sq. miles), is roughly the same size as the city of #Boulder (24 sq. miles): URL ...', 'Other Useful Information']
# Other Useful Information
# ['#bushfires #nswfires #sydney URL', 'Not applicable']
# Not applicable
# ['In Focus - Colorado Wildfires: The Aftermath - The Atlantic URL', 'Other Useful Information']
# Other Useful Information
# ...
# Other Useful Information
# ['#boulderfire viewed from NCAR. Flames were visible at ridge but air drops seem to be preventing rollover into canyon. URL', 'Other Useful Information']
# Other Useful Information
# ['Thoughts to our stunning wildlife caught amongst the bushfires- so many native animals will sadly perish #nswfires #Sydney', 'Sympathy and support']
# Sympathy and support
# ['RT @TyCBS4: This sign welcomes evacuees back into the Soldier Canyon area #HighParkFire @CBSDenver URL', 'Affected individuals']
# Affected individuals
# ['RT @TigerAngel2: RT @HumaneSociety: Not affected by #highparkfire? Help @LarimerHumane by donating wet dog/cat food, or on their site ht ...', 'Donations and volunteering']
# Donations and volunteering
# ["RT @PMOnAir: Adam Bandt is a disgrace. I can't think for a more inappropriate tweet. #nswfires #sydfires #pmlive  URL", 'Other Useful Information']
# Other Useful Information
# ['Please pray for Colorado Springs. Our city is on fire.', 'Sympathy and support']
# Sympathy and support
# ['RT @robrfs: People need to understand that the danger is not over for people on any of the active firegrounds. Many hours to go. #nswfires', 'Other Useful Information']
# Other Useful Information
# ['RT @cnnbrk: Officials: At least 57 bush fires rage in Australia; state of emergency declared URL', 'Caution and advice']
# Caution and advice
# ['Follow the #nswfires coverage with our live blog @smh URL', 'Other Useful Information']
# Other Useful Information
# ["RT @exposeliberals: Obama's silence on the wildfires in Colorado is deafening #tcot #tlot #obamafail", 'Other Useful Information']
# Other Useful Information
# ["It could be worse. I could be in Colorado where I can't have fireworks AND my neighborhood is on fire. #iwillstopwhiningnow", 'Sympathy and support']
# Sympathy and support
# ["RT @adambombshow: to all our Colorado Springs listeners, we're praying for you. crazy fires URL", 'Sympathy and support']
# Sympathy and support
# ['RT @Bewickwren: #WaldoCanyonFire 11:21 p.m. Evacuations in Manitou Springs as fire makes late-night run, dispatchers say. #COFire  URL ...', 'Other Useful Information']
# Other Useful Information
# ['View from my desk earlier #sydneyfires #sydney #australia #smoke #scary #city #cbd #orange #apocalypse… URL', 'Other Useful Information']
# Other Useful Information
# ["RT @marykissel: Australia's PM fights fires (literally) for 14 hours as 'volunteer firey.' Wow.  URL via @australian", 'Donations and volunteering']
# Donations and volunteering
# ['RT @COEmergency: #HighParkFire Disaster Recovery Center opened this morning at CSU Johnson Hall to bring together resources. URL ...', 'Donations and volunteering']
# Donations and volunteering
# ['High Park Fire in Colorado URL', 'Other Useful Information']
# Other Useful Information
# ['RT @Coloradoan_TH: Photos from one of the wildland firefighters working here: RT @BrittIronShell: When we had night shift #HighParkFire  ...', 'Affected individuals']
# Affected individuals
# ['RT @ABCNews24: Now #NX with @mattcargill: @mpesce on future cities, US spying fallout + #nswfires online with @JulesHolman. Watch URL', 'Other Useful Information']
# Other Useful Information
# ['Follow @TaliahBeatz RT @ressiVdanor RT @HADIARE: #OPENFOLLOW Fort Collins, Colorado Wildfire Spreads As New Mexico ...  Follow @JiNxBeatz', 'Other Useful Information']
# Other Useful Information
# ['All affected by the Colorado Springs #WaldoCanyonFire.are in my thoughts and prayers today.', 'Sympathy and support']
# Sympathy and support
# ['@alan_arnette Moore Animal Hosptal in FC offering free small animal boarding and pick up for #highparkfire evacuees. 970-560-0452 for info.', 'Donations and volunteering']
# Donations and volunteering
# ['Emergency Warning - Hank St Fire (Heatherbrae) URL #NSWRFS #nswfires', 'Caution and advice']
# Caution and advice
# ['RT @GusWhyte: The fires in Eastern NSW makes me very sad, I feel for all the ppl impacted, I can only imagine how frightening it would be i…', 'Sympathy and support']
# Sympathy and support
# ['This is just horrible #nswfires URL', 'Other Useful Information']
# Other Useful Information
# ['Colorado Springs Relief Update URL Thank you to everyone helping out in this difficult time.', 'Sympathy and support']
# Sympathy and support
# ['#RedSun #SmokedClouds #SydneyFires #SummerGonBurnErrthang! URL', 'Not applicable']
# Not applicable
# ['RT @ReutersUS: Firefighters gain upper hand on Colorado wildfires, gird for long season URL', 'Other Useful Information']
# Other Useful Information
# ['Be praying, this is very close to where my parents and sister live...WALDO CANYON FIRE - Colorado Springs Gazette, CO URL', 'Sympathy and support']
# Sympathy and support
# ['RT @BrianCHouston: Could you please pray for our home state in Australia, where the bush fire situation continues to worsen in treacherous …', 'Sympathy and support']
# Sympathy and support
# ['Colorado to double wildfire crews URL', 'Other Useful Information']
# Other Useful Information
# ['RT @climatehawk1: Climate Code Red: Is Abbott govt fiddling while NSW burns?: URL #climate #globalwarming #fire #divest', 'Other Useful Information']
# Other Useful Information
# ['RT @Misschicka114: HELP ARRIVES!! A convoy of around 40 fire trucks from South Australia spotted coming up the Hume Highway URL', 'Other Useful Information']
# Other Useful Information
# ['RT @NSWRFS: 4:05pm Media briefing with Commissioner Shane Fitzsimmons being live streamed now - URL #nswfires #NSWRFS', 'Caution and advice']
# Caution and advice
# ['Praying for everyone in Colorado affected by the fire to keep safe!', 'Sympathy and support']
# Sympathy and support
# ['The fires in the Blue Mountains are burning over a very wide area. #NSWRFS URL', 'Caution and advice']
# Caution and advice
# ['#Evacuation center Cache La Poudre Middle School 3515 West County Road 54G in Laporte. #Colorado #Wildfire', 'Caution and advice']
# Caution and advice
# ['Check out this item I found on eBay: URL All proceeds go to the NSW fire Victims Pls #RT  ★TY', 'Donations and volunteering']
# Donations and volunteering
# ['RT @9NEWS: LIVE #highparkfire media briefing: URL', 'Other Useful Information']
# Other Useful Information
# ["Australia fire threat 'averted' URL", 'Other Useful Information']
# Other Useful Information
# ['@Sandra_Sully: .@_AdamTodd: Bushfires at Springwood as the sun sets #nswfires #eyewitnessnews URL', 'Other Useful Information']
# Other Useful Information
# ['RT @DenverChannel: RT @1310kfkanews: @larimersheriff just told 1310 KFKA the acreage of the #Highparkfire may grow significantly today', 'Other Useful Information']
# Other Useful Information
# ['Fitz 7:05AM presser: 70-80km/h SW winds expected again today for #BlueMountains. #nswfires', 'Caution and advice']
# Caution and advice
# ['Photographer was in Glacier View as #HighParkFire evacuations were declared. His photo gallery: URL', 'Other Useful Information']
# Other Useful Information
# ['For the Santa Messa tomorrow a special prayer for all who have already lost their homes in our bush fires in Australia dear Papa Francesco', 'Sympathy and support']
# Sympathy and support
# ["Colorado wildfire of 'epic proportions' displaces 32,000: Firefighters again will battle inferno-like conditions... URL", 'Affected individuals']
# Affected individuals
# ['RT @MGHReeves: #NSWRFS crews working in hot, smokey and difficult conditions at Bilpin. Pic from #Inglesiderfs URL', 'Other Useful Information']
# Other Useful Information
# ['RT @ABCNews24: #BREAKING: Emergency warning for bushfire at Browns Rd, Port Stephens NSW. Fire info at URL or @NSWRFS', 'Caution and advice']
# Caution and advice
# ['Great, Boulder on fire too', 'Other Useful Information']
# Other Useful Information
# ['@Harry_Styles can you just do a quick shout out to all of the fire victims in Colorado? over 32,000 are evacuated...it would mean a lot!(:', 'Sympathy and support']
# Sympathy and support
# ['RT @thetodayshow: UPDATE: 83 fires burning, 19 uncontained. 81 homes destroyed, 37 damaged across NSW. @deborah_knight #today9', 'Infrastructure and utilities']
# Infrastructure and utilities
# ['Thoughts and prayers with everyone who has been affected by the fires and hope they can stay strong in the upcoming days #nswfires', 'Sympathy and support']
# Sympathy and support
# ['RT @TCorbett2908: “@SBSNews: Comment: Is it right for @AdamBandt and others to link #nswfires with climate change policy? URL', 'Other Useful Information']
# Other Useful Information
# ['Of course it did. RT @drgrist: My new post: Did climate change ’cause’ the Colorado wildfires? URL', 'Other Useful Information']
# Other Useful Information
# ["People of NSW, be careful because there's fires spreading! Stay safe everyone! URL", 'Other Useful Information']
# Other Useful Information
# ['Fire brings Colorado Springs evacuations  URL', 'Affected individuals']
# Affected individuals
# ['#NSWFires 2013 URL', 'Other Useful Information']
# Other Useful Information
# ["RT @kumitaguchi: In case I'm sent to the bushfires, grab bag preparation #firstaid #water #food #nswfires URL", 'Affected individuals']
# Affected individuals
# ['RT @nswfire: URGENT MESSAGE RESIDENTS NORTH OF #SWANSEA #NSW YOU ARE IMMINENT DANGER #EVACATE NOW GO TO #SWANSEA NORTH ONLY #FIRE UNDERGROU…', 'Caution and advice']
# Caution and advice
# ['How Social Media Is Helping Colorado Wildfire Relief URL', 'Donations and volunteering']
# Donations and volunteering
# ['RT @jerradtyson: My thoughts are w evry1 affected by the current bush fires. Stay safe &amp; be smart! Pic: smoke blanketing West Sydney URL', 'Sympathy and support']
# Sympathy and support
# ['RT @nzherald: The front page of today’s New Zealand Herald: “Inferno: The Great Escape” URL #nswfires URL', 'Other Useful Information']
# Other Useful Information
# ["RT @JenBrockie: If you're yet to head home, and get asthma, grab a puffer. #nswfires #bushfires", 'Other Useful Information']
# Other Useful Information
# ['RT @ronanofficial: Our thoughts and prayers are with everyone caught or involved in the #nswfires.', 'Sympathy and support']
# Sympathy and support
# ["Fire threat to Australia's Blue Mountains 'averted' - BBC News: Sydney Morning HeraldFire threat to Australia'... URL", 'Other Useful Information']
# Other Useful Information
# ['#HighParkFire from I-25. URL', 'Other Useful Information']
# Other Useful Information
# ["RT @abcnews: .@barryofarrell : We're planning for the worst but hoping for the best. #NSWfires URL", 'Sympathy and support']
# Sympathy and support
# ["#newbedon 6/28/2012 9:25:11 AM Colorado fire near Pike's Peak forces 11,000 from homes URL", 'Affected individuals']
# Affected individuals
# ["RFS warns of forced evacuations We want houses standing, but if they are not standing, we don't want bodies in them #nswfires", 'Affected individuals']
# Affected individuals
# ['#abcnews Live: RFS crews race to gain upper hand on NSW fires ahead of extreme conditions tomorrow via  URL', 'Other Useful Information']
# Other Useful Information
# ['RT @AFSpace: AFSPC Vandenberg Hot Shots are on the ground in Colorado Springs helping fight the #WaldoCanyonFire as we speak: URL ...', 'Infrastructure and utilities']
# Infrastructure and utilities
# ['Summer is just starting. there has been over 100000 acres of land &amp; homes burned up in Colorado from wildfires my gut tells me long summer', 'Other Useful Information']
# Other Useful Information
# ['New Boulder Fire Prompts Mandatory Evacuations: A fire that erupted in Boulder County Tuesday afternoon -- being... URL', 'Caution and advice']
# Caution and advice
# ['RT @9NewsSyd: Insurance companies are paying over $2 million a day for victims of the recent #nswfires disaster. Read more: URL', 'Other Useful Information']
# Other Useful Information
# ['RT @abcnews: Stunning images from Sydney and surrounding areas of the #nswfires emergency URL', 'Other Useful Information']
# Other Useful Information
# ['#australia #news Boy, 11, charged over starting two fires near Newcastle - The Australian URL', 'Other Useful Information']
# Other Useful Information
# ['RT @smh: Editorial: Bushfire disaster reminds us we are one community. URL #nswfires', 'Other Useful Information']
# Other Useful Information
# ["RT @TripleM_NRL: Say again over. There's no time to leave. It's too late Mind blowing footage from the #nswfires frontline #heroes URL", 'Sympathy and support']
# Sympathy and support
# ['To all drivers out on fire-torn roads around #Sydney: Please be safe &amp; make sure to follow all official instructions. #nswfires #safetyfirst', 'Caution and advice']
# Caution and advice
# ['@GerardKapraun 125 (IBD) Al Gore Throws Another Climate Lie On The Barbie - Blames Australia Fires On Climate Change URL', 'Other Useful Information']
# Other Useful Information
# ['RT @doyourpartorg: Thunderstorms expected to affect NW portion of the #HighParkFire by 2:30 pm today - 20-30 mph gusts w/light to modera ...', 'Other Useful Information']
# Other Useful Information
# ['RT @TimothyWhalin: The #WaldoCanyonFire has increased to 15,324 acres. Please continue to pray for Colorado Springs.', 'Sympathy and support']
# Sympathy and support
# ['Wed Night:Wednesday Night Mostly cloudy,Low around 66.Southwest wind 5 to 7 mph be safe &amp; smart #Utah #4thOfJuly #fireworks #Wildfire', 'Not applicable']
# Not applicable
# ['RT @instagram: Frightening photo of the Colorado #wildfire by @dredayy66: URL Please stay safe!', 'Other Useful Information']
# Other Useful Information
# ['my thoughts and prayers go out to all the people affected by the #nswfires ♥♥', 'Sympathy and support']
# Sympathy and support
# ['RT @unisdr: 17 Oct NASA image gives an idea of the scale and extent of the bush fires raging in New South Wales #australia URL', 'Other Useful Information']
# Other Useful Information
# ['Fear of super-fire in Australia may force mass evacuations affecting tens of thousands of people URL', 'Caution and advice']
# Caution and advice
# ['RT @9NewsNOW: The latest details on the #nswfires, including the RFS aircraft that crashed on the NSW south coast. @samvadas9 reports in #9…', 'Other Useful Information']
# Other Useful Information
# ["RT @HuffingtonPost: LOOK: Colorado's multiple wildfires as seen from space URL", 'Other Useful Information']
# Other Useful Information
# ['Fears Increase That Aussie Super-Fires May Merge Outside Sydney URL', 'Other Useful Information']
# Other Useful Information
# ['RT @wilw: RT @SidSuicide Can you please RT? Visit URL  to help with the Colorado fires. #WaldoCanyonFire Help if you  ...', 'Donations and volunteering']
# Donations and volunteering
# ["RT @krONik: If Tony Abbott gets burnt to cinders 'fighting' #NSWfires #greghuntresearch shows Julie Asbestos Bishop becomes #PrimeMoron! O …", 'Not applicable']
# Not applicable
# ['RT @nourbaby: Those Colorado wildfires look scary. Prayers to everyone near there', 'Sympathy and support']
# Sympathy and support
# ['RT @YourAnonNews: Colorado Springs, CO is on fire. 65mph winds blew it into the city today. Looked like Armageddon. #WaldoCanyonFire | h ...', 'Other Useful Information']
# Other Useful Information
# ['The firies seem to be doing an amazing job. Keep it up. #auspol #nswrfs', 'Sympathy and support']
# Sympathy and support
# ['2 wildfires in Boulder County. We can see smoke to the north.', 'Other Useful Information']
# Other Useful Information
# ['RT @DaniIsdale: Leaving the newsroom now, thinking of all the #nswrfs volunteers who will keep working all weekend to save houses and lives…', 'Sympathy and support']
# Sympathy and support
# ["amazing. summer hasnt even started in australia, and it's already forest fires.", 'Sympathy and support']
# Sympathy and support
# ['RT @702sydney: Chain Valley Bay fire hits residential areas. #SydneyFires #nswfires via Paige Thomas URL', 'Infrastructure and utilities']
# Infrastructure and utilities
# ['Bush fires in the middle of October in Sydney is probably a great sign for the future of humans on this planet, right guys?', 'Other Useful Information']
# Other Useful Information
# ["LetYouKnow: Australia fire threat 'averted': Australian fire officials say the threat t... URL URL", 'Other Useful Information']
# Other Useful Information

# %%
samples
# Out:
# [('RT @NationalPrayer: PRAYER ALERT: Remain in prayer for those fighting the #WaldoCanyonFire in Colorado Springs &amp; the 32,000+ people  ...',
#   5),
#  ('RT @akcdoglovers: AKC CAR donates to help displaced animals in the Colorado wildfires URL',
#   6),
#  ('RT @Sarakateee: RIP Colorado. Cause of death: fire.', 5),
#  ('@PortDouglasSK yes some good rain would be very beneficial #nswfires', 3),
#  ('Wildfires worsen in Colorado, 32,000 flee homes URL via @reuters', 0),
#  ('RT @SheilaWalsh: Praying for divine intervention  and protection for all those affected by the fires in Colorado Springs. #waldocanyonfire',
#   5),
#  ('RT @PadsCast: The fires are in Colorado Springs but there is a haze in the sky in Denver and you can smell the smoke because of the high ...',
#   3),
#  ('RT @KimberleyL: :) RT @alexlee_24: @KimberleyL Two fires at Sydney Water and Sydney Aquatic Centre within a week. When did fire develop a s…',
#   2),
#  ('Thinking of my bestie in colorado.. So many wildfires and not the latest one is close to her house and work. 😳💔',
#   5),
#  ("RT @TheSwearyNews: Australia's on fucking fire again. Firefighters have blamed Harold Bishop for smoking in bed again.",
#   3),
#  ('RT @james_willstrop: Whilst the floods cause havoc in Yorkshire, Colorado is burning. Wild fires are closing in on Estes Park! Desperate ...',
#   3),
#  ('RT @MalloryOnTravel: Colorado Springs Fire Spreads to Tourist Areas: Pikes Peak, Rocky Mountain Park URL #travel #ttot',
#   4),
#  ('Wildfires burn across Colorado, thousands evacuated: A spate of wildfires were burning across Colorado on Sunday... URL',
#   0),
#  ('Hearing sad news the little prawn on the A43 at Crangan Bay (west of Catherine Hill Bay) has gone up in flames. #nswfires',
#   5),
#  ('Amazing skies in Sydney at the moment with bush-fires nearby. URL', 3),
#  ('RT @atmosphere: our thoughts go out to the people in colorado dealing with the wildfires.',
#   5),
#  ("RT @brookejarvis: Colorado's on fire. Livestream of the fire prompting evacuation warnings in Boulder: URL #flagstafffi ...",
#   1),
#  ("Plz Flw @RedneckRag: Colorado fire claims first #victim, ranks as state's most... URL  #ColoradoSprings #firstvictim",
#   0),
#  ('Colorado fires sweep social media sites as readers look for info - Denver Post URL',
#   3),
#  ('@BiancaGriffith #boulder #FlagstaffFire Esto es de Película Americana... URL',
#   3),
#  ('RT @therealmalcolm: Yo Australia send my prayers hope people are safe from the fires @MKTOAustralia',
#   5),
#  ('C10 Fire Safety Engineer Sydney URL  #ENGJobs', 3),
#  ("Crisis Averted For Now In Australia's Fight Against Fires URL", 1),
#  ('RT @RebelWilson: Thinking of everyone in Western Sydney who are being affected by the bush fires x be safe x',
#   5),
#  ('Hope everyone in Greeley ok with wildfires in Colorado!', 5),
#  ('#HighParkFire live briefing: Bill Hahnenberg, cmdr: The prognosis for the next day — a little better, but extreme weather conditions.',
#   3),
#  ('Forest fires in Colorado! #awful URL', 3),
#  ('RT @abcnews: NSW RFS Deputy Commissioner Rob Rogers describes Lithgow blaze as a monster fire. More: URL #NSWfires',
#   1),
#  ('Colorado wildfires: Several fires explode across Front Range URL', 3),
#  ("Massive Australia bush fire 'started by Defence Department' via @Telegraph URL",
#   3),
#  ('Our Salvos Store in Springwood is open today offering support and practical assistance for bushfire affected locals #nswfires',
#   6),
#  ('Top Story: Australia bush fire threat easing: Wildfires threaten the western suburbs of Austral... URL #ERMmedia @CNN',
#   4),
#  ('RT @DanniiMinogue: NSW Australia: 59 bush fires. Hoping today luck is on our side for residents and fire fighters.🍀🐨',
#   5),
#  ('We will try and keep our page up to date with fire updates around NSW as they come to hand',
#   1),
#  ('Please join us in praying for the fire fighters who are bravely combating the bushfires across NSW. Our prayers... URL',
#   5),
#  ('#nswfires #backburning operations  If you see an unattended #nswfire call Triple Zero, (000) immediately.  Do not call 000 to report smoke',
#   1),
#  ('Forest / Wild Fire - Australia - Australia URL', 3),
#  ("RT @BBCWorld: Did explosives from military exercise start massive bush fire in Australia's New South Wales? URL",
#   3),
#  ('RT @ElaineByrne: The land burnt by #nswfires in Australia so far is bigger than the island of Ireland. #scaryshit',
#   3),
#  ('RT @NSWRFS: Infrared image from #Lithgow fire - fire is spotting ahead, very intense activity. #NSWRFS #nswfires URL',
#   3),
#  ('RT @ABCNews24: #BREAKING: NSW Police confirm pilot deceased in #Ulladulla #nswfires plane crash  #bushfires #ABCNews24',
#   0),
#  ('RT @NSWRFS: Hall Rd Fire, Balmoral Village (Sthn Highlands) Fire has crossed railway line at Yanderra. Main Southern Railway clsed #nswfires',
#   1),
#  ("RT @jrmontag: I usually love the smell of a campfire. Not so much when it's burning my town. #FlagstaffFire",
#   0),
#  ('#fnre #nswbushfires Regular bushfire updates available through NSW RFS URL URL',
#   1),
#  ("Front page shocker: A Colorado family learns - in a shocking way - that their home has been lost to fire. CNN's ... URL",
#   0),
#  ('RT @pelagicpictures: Phil and Sue Dunlop search for valuables from the ashes of their home in Winmalee. @photosSMH #nswfires @smhnews URL',
#   0),
#  ('#nswfires Nov01 16:00 70km ESE of Walcha /Oxley Hwy Kangaroo Flat Rd &amp; Racecourse Trail #outofcontrol #bushfire 150ha URL',
#   1),
#  ('One of the Colorado wildfires has burned an area greater than Seattle URL via @KIRO7Seattle',
#   3),
#  ('@twitterau during the #nswfires', 3),
#  ("RT @Buzzoot: In solidarity with our brothers and sisters in Colorado, let's hope and pray for a quick end to the fires #PrayForRainInCo  ...",
#   5),
#  ('RT @kariontour: Prayers going out too all the people in Colorado and the other states dealing with these deadly fires.',
#   5),
#  ('Surging Colorado wildfires forcing tens of thousands to flee  URL', 0),
#  ('RT @NationalPrayer: Heavenly Father, please be with the men and women fighting the #WaldoCanyonFire in the Colorado Springs area. Please ...',
#   5),
#  ('Airstrip in Colorado Springs.', 2),
#  ('RT @OwenNix: Sydney International Regatta Centre, doubling as a helicopter refueling station &amp; water source #nswfires URL',
#   3),
#  ('For the latest on the massive #HighParkFire, follow @CBSDenver and get the details here: URL',
#   3),
#  ('RT @NSWRFS: Thank you to the thousands of firefighters who have so bravely fought fires in difficult conds. #NSWRFS #nswfires URL',
#   5),
#  ('Colorado Fires... Flying W - URL URL #FLYINGWRANCH #COLORADOFIRES', 3),
#  ('@justinbieber  please bless my home Colorado springs is on fire :(', 5),
#  ('RT @9NewsSyd: To put the #StateMineFire in perspective, this is how big it would be if it was burning in #Sydney. #nswfires URL',
#   3),
#  ('RT @Nyx2701: “@9NewsSyd: #Springwood fire now threatening St Columba’s School. #nswfires URL #BlueMountains #BushFires',
#   1),
#  ('#newbedon 6/28/2012 10:00:53 AM Colorado fire near Pikes Peak forces 11,000 from homes URL',
#   0),
#  ('RT @nswfire: #nswfires status 11:45 URL Fire #advice #mountyorkroad 06:05 #linksviewroad  06:04 #hallroadfire 06:02 #how…',
#   3),
#  ('RT @BULMKT: There is no Climate Change link to the #nswbushfires but there is a direct link between #Ecotardism and Adam Bandt #auspol',
#   3),
#  ("its a shame Colorado couldn't have all this rain :( #wildfires", 3),
#  ('Homes at risk from Colorado wildfire: Hundreds of families took refuge early Monday at a northern Colorado ... URL #CNN',
#   4),
#  ("RT @HumaneSociety: we'll second that! RT @nalowry: Shout out to all local news agencies keeping people updated on the #highparkfire",
#   5),
#  ('#nswpol #auspol #BlueMountains #Blackheath #MtVictoria #nswfires Heroes =@NSWRFS @FireRescueNSW  Pg2  newsletter URL',
#   3),
#  ('RT @arschmitty: Praying for those who have been affected by the Colorado fires and hoping for the best 💜💜',
#   5),
#  ('MY GOODNESS! My hometown of Colorado Springs seems to be in fire turmoil! What is going on down there!? If... URL',
#   5),
#  ('RT @NSWRFS: Commissioner: Use today to prepare. Use tonight to check your Bush Fire Survival Plan. #nswfires #NSWRFS URL',
#   1),
#  ("Beautiful morning in Sydney, sunshine and clear sky's - I hope this weather eases conditions for the fires across NSW.",
#   5),
#  ('RT @reporterherald: #HighParkFire making push north over Red Feather Lakes Road. All of Glacier View, and more, evacuated. URL ...',
#   3),
#  ('AUSTRALIA: Australia merges  blazes to prevent ‘mega-fire’: Firefighters battling unseasonable wildfires in so... URL',
#   3),
#  ('RT @KerrinJeromin: Wow. terrible MT @wunderground @SeanSublette13  Terrifying fire in Colorado Springs, CO. Evacuations underway URL ...',
#   0),
#  ('RT @Neinusername: Prime Minister Tony Abbott joins Davidson Rural Fire Brigade to fight NSW bushfires URL #auspol',
#   3),
#  ('Man. You would swear Colorado was on fire.....', 2),
#  ('RT @NSWRFS: Linksview Rd (Springwood): An Air crane has been deployed to assist crews. #nswfires #NSWRFS',
#   3),
#  ('Unrelenting fires burn Australia: At least 57 bush fires are raging in eastern Australia, including 14 that ar... URL',
#   3),
#  ('RT @NSWRFS: Hall Road Fire: An evacuation centre has been set up in Picton at the Brethren Church, Wonga Rd Picton. #nswfires #NSWRFS',
#   1),
#  ('RT @cmyers75: “@cmyers75 “@Engadine_RFB “@BrentSGibson: Smoke seen  Williamtown Airport  #nswfires #Newcastle URL @ten…',
#   3),
#  ('Smoke haze blankets #Illawarra URL via @illawarramerc #nswfires', 3),
#  ("Australian fire crisis eases: Drop in temperature has slightly eased the bushfire crisis in Australia's New So... URL",
#   1),
#  ("Top Story: Fears of 'mega-fire' forming: Australia firefighters are worried that two separate f... URL #ERMmedia @CNN",
#   3),
#  ('RT @7NewsSydney: CHOPPERCAM: Emergency warning issued for area of Stockrington Road, west of the M1, heading towards Minmi #NSWfires URL',
#   1),
#  ('Greg Hunt quotes Wikipedia to refute link between #NSWFires and #ClimateChange. I quote @mariekehardy: Are.  You.  F***ing.  Kidding.  Me.',
#   3),
#  ('#Davis Colorado Springs Waldo Canyon wildfire forces thousands to flee flames URL',
#   0),
#  ('RT @TimesCall: #HighParkfire 15% contained, but jumps the Poudre URL', 3),
#  ("RT @bazarazzi: Government cut in aid 'heartless'. Appalling. Shame on you @MichaelKeenanMP. URL #nswfires",
#   5),
#  ('RT @diversionary: Whoa. RT @workmanalice: Amazing photo from a friend in Katoomba on the road to Blackheath. #nswfires URL',
#   4),
#  ('Be safe my south boulder friends. This one breaks my heart :( #flagstafffire #tooclosetohome URL',
#   5),
#  ('RT @SkratchLabs: Check out @cofiresale and bid on a year supply of @SkratchLabs to help raise money for the Colorado Fires.  Please RT!',
#   6),
#  ("RT @photogramel: The NSW Fire &amp; Rescue Service was set a $11M savings target by the O'Farrell government. URL",
#   3),
#  ('RT @mattdoran22: Reports a chopper has crashed fighting fires near Ulladulla #nswfires #eyewitnessnews @channeltennews',
#   0),
#  ("NSW RFS: Hall Rd fire likely to be 'Contained' by this afternoon. Thank you to all emergency services personnel for their hard work!",
#   5),
#  ('RT @channeltennews: If you need to stay up to date with bushfire conditions – make sure you also follow @NSWRFS on twitter. #SydneyFires #n…',
#   1),
#  ('Latest on the #nswfires here URL', 3),
#  ('We are sending our positive thoughts to all who are affected by the fires in our beloved home state of Colorado.',
#   5),
#  ('RT @ABCNews24: Shane Fitzsimmons: There are more than 60 fires across NSW, 15 of those remain uncontained #nswfires #bushfires',
#   1),
#  ("I've got family in Colorado Springs, so I've been keeping a close eye on the wildfires through the #nws website.  URL",
#   0),
#  ("RT @abcnews: #Breaking: A state of emergency is declared in NSW by Premier Barry O'Farrell. Live: URL #NSWfires",
#   1),
#  ("#AusPol @TonyAbbottMHR quotes Dorothea Mackellar to explain Australia's ability to cope with fire: URL",
#   3),
#  ("What a week it's been!  #highparkfire you better behave today.  URL", 5),
#  ('RT @gcnelson: A weary firefighter catches a well earned rest as the worst appears over. @abcnews #NSWfires URL',
#   0),
#  ('Our hearts go out to all those affected by the terrible fires. Stay safe. NSW Rural Fire Service - Bush Fire... URL',
#   5),
#  ('Being able to see the forest fires in New Mexico/Colorado from our hotel #sketchy',
#   0),
#  ('Saying that, though, my thoughts go out to those who are affected by this horrible natural disaster. #nswbushfires',
#   5),
#  ('RT @KDVR: Pre-evacuation notice for the city of #Boulder URL #flagstafffire',
#   1),
#  ('RT @RMACCFireinfo: Tanker update: 6 pm, 37 drops, 58,557 gals retardant on #HighParkFire from #JeffcoAirTankerBase.... URL',
#   3),
#  ("Fires in Sydney's Blue Mountains have destroyed nearly 200 homes. #nswfires URL",
#   4),
#  ('New forest fire just broke out in Boulder! 14 forest fires in CO right now! Praying my heart out!',
#   5),
#  ('URL #boulderfire', 3),
#  ('RT @Meagan9News: Concern today for #highparkfire: Explosive weather conditions because of heat, high winds and low humidity.',
#   3),
#  ('@9NEWS: Incident command: NE &amp; SE corners, S flank of #HighParkFire are hot. East flank, which is closest to Ft Collins is calm',
#   3),
#  ('RT @HaydosTweets: Final shout out! Thoughts and prayers tonight for the brave folk of #nswfires #GodBless can I request my followers to re …',
#   5),
#  ('RT @Reuters: Monster Colorado wildfire rages; Obama plans visit URL', 3),
#  ('RT @ksbw: Hundreds of homes destroyed in raging Colorado fire: Colorado Springs officials said Thursday that hundreds of homes... URL ...',
#   4),
#  ('RT @NSWRFS: Watch and Act - Hall Road (Southern Highlands / Wollondilly).  URL Picton Rd now open #nswrfs #nswfires',
#   1),
#  ("Damage Assessment teams for #HighParkFire being assembled to determine what' structures have been burned, damaged or untouched.",
#   4),
#  ('News Update Furious Wildfire in Colorado Leaves Destruction in Its Wake URL',
#   4),
#  ("#highparkfire It's a slow progress, but we need to have favorable weather and we've had that the last couple of days.",
#   3),
#  ('Smell of Ash in Sydney  is a reminder of how close we are to the fires . My family home burnt down in 1980 so understand the trauma#fires',
#   0),
#  ('RT @PhotoWil: The only thing I can do to help Colorado is wait til all the fires are out, then spend my tourist $ there asap. Hope you w ...',
#   5),
#  ("Video: AP  - AP Top Stories: Here's the latest news for Tuesday, June 26: Colorado fires rage in hot, dry condit... URL",
#   3),
#  ('RT @bouldercounty: Material donations are NOT needed for the #FlagstaffFire at this time. Financial support is the best way to help. Inf ...',
#   6),
#  ('News by BBC Australia bush fires set to worsen: Australian firefighters warn that the return of hot weather an...  URL',
#   1),
#  ('RT @thewest_com_au: It will be a miracle if no lives are lost to NSW bushfires: Premier. [with videos] #NSWfires URL',
#   3),
#  ('@ChilledChaos If you have time could you do a shout-out for the Creatures charity stream for the Colorado Wildfires? URL',
#   6),
#  ('Photo: Colorado wildfire near Air Force’s Falcon Stadium URL', 3),
#  ('RT @heldavidson: Southern Highlands bushfire upgraded to emergency warning. @guardianaus #nswfires live blog URL',
#   1),
#  ('RT @7NewsSydney: GALLERY: #NSW bushfire devastation in pictures: URL #nswfires',
#   3),
#  ("RT @AP: AP VIDEO: Colorado wildfires double in size overnight, 'not remotely close to being contained': URL -EF",
#   3),
#  ('FOLLOW AND RETWEET FOR RAIN FOR FRONT RANGE COLORADO AND THE SPRINGS PLEASE - GOD BLESS AND THANKS! -... URL',
#   5),
#  ('Firies to link two Blue Mountains Fires: A desperate backburning operation in the NSW Blue Mountains is underway... URL',
#   3),
#  ('There is a growing fire near Norwest Hospital, NSW.  Fire brigade is in attendance.',
#   1),
#  ('Australia weather increases threat of fires: Fifteen fires continue to burn out of control in  New South Wales... URL',
#   4),
#  ('PRAYING.. RT @leighramsey: Colorado Fire: Worst in 32 yrs. Perfect storm apparently. 32 thousand being evacuated URL',
#   0),
#  ('RT @DrOz: My prayers go out to everyone in the Colorado Springs area. Stay safe!',
#   5),
#  ('RT @dbouwman: Pretty smoke free day Fort Collins, but the smoke is settling in now... closing windows! #highparkfire',
#   0),
#  ('#NSWFIRES  #MEDOWIE #NSW  Residents in this areas are advised to #shelter_in_place as the #firefront approaches URL',
#   1),
#  ('RT @stormchaser4850: Developing: Around 32,000 evacuated in the Colorado Springs, CO area due to destructive wildfire via press conference',
#   0),
#  ('RT @NSWRFS: If you find an injured native animal, call WIRES 13000WIRES or DPI for livestock.  URL @WIRES_NSW #nswfires',
#   2),
#  ('RT @denvernews: Denver News: Colorado to sizzle with record heat Monday, fire danger is high URL',
#   3),
#  ('RT @AlexChesser: Three big days ahead for firefighters. Help us by planning ahead &amp; knowing what you will do if threatend by #nswfires URL',
#   1),
#  ("The copter is on the way to the #HighParkFire. We'll be airing it live throughout our coverage. You can also follow @CodyCrouch for pics.",
#   3),
#  ('@d4_aspen Hey Asp! I have friends who live in Colorado Springs,CO and they are evacuating the city becuz of wild fires. Can you please (c)',
#   0),
#  ('Think and Pray for Colorado Springs Residents- FIRE- it could happen anywhere-Be Prepared!',
#   5),
#  ('@RADickey43 Please RT. Colorado Springs is suffering badly from a large forest fire. Text the word REDCROSS for a $10 donation. Thank You',
#   6),
#  ('Colorado wildfires: Real-time social media response map URL via @denverpost',
#   3),
#  ('Photo | The @RBB_net show a sign of respect to the victims of the NSW fires. #GoWanderers #aleague URL',
#   5),
#  ("Despite the weekend's cooler temperatures, crews are conducting critical backburning operations. There are still 53 fires burning. #nswfires",
#   3),
#  ('RT @ch150ch: Abbott (who claims exps for runs, swims &amp; bike rides) changes rules so less people to get #nswfires disaster payment URL',
#   3),
#  ('RAIN ALREADY #COLORADO.  It looks like Armageddon over there.  #flagstafffire',
#   5),
#  ("At least 57 bush fires are raging in eastern Australia, including 14 that aren't contained, officials said. URL",
#   3),
#  ('@THEKINGColucci Australia Fires: Military Investigates Blaze: The military reveals it was conducting an explosives training...  @deadmau5',
#   3),
#  ("RT @triplejHack: We're talking about whether it's too early to blame climate change for the #nswfires. Are you worried these are happening …",
#   3),
#  ('RT @FeedingAmerica: The outpouring of support for @careandsharefb is awesome! They are helping the Colorado fire evacuees URL ...',
#   6),
#  ('RT @bigbooty_JUDYYY: Prayers go out to everyone affected by these wildfires in Colorado! The Lord is the ultimate protector, trust in Him.',
#   5),
#  ('RT @treisiroon: Military live ordinance exercises was cause of one of the fires raging in #Australia URL v @jaraparilla',
#   3),
#  ("#bushfires 'Significant' number of homes lost as 100 wildfires rage across Australian state (from @AP) #nswfires URL",
#   4),
#  ("RT @DanMacPherson: Just up to speed on today's horrific fires. Thoughts with all involved. Heartbreaking. Just heartbreaking.  #nswfires",
#   5),
#  ("I've figured out why Colorado is on fire. Al Qaeda hacked the CIA weather control satellites using a virus that was implanted in Osamas DNA",
#   3),
#  ('@csgazette reporting that Colorado Springs is under another red flag warning today. #WaldoCanyonFire',
#   1),
#  ('Please keep Colorado and Florida in your prayers. Wildfires and flooding...',
#   5),
#  ('RT @SalArmyEDS: Help #SalvationArmy assist disaster survivors - T.S. #Debby URL &amp; Colorado #wildfires URL ...',
#   6),
#  ('Federal firefighters go uninsured: As brutal wildfires spread in Colorado, federal fighters, along with state an... URL',
#   3),
#  ('RT @850KOA: Devasting update from #HighParkFire.  112 homes lost.  More likely to be counted in the coming days.',
#   4),
#  ('RT @cnnbrk: Officials: At least 57 bush fires rage in Australia; state of emergency declared URL',
#   1),
#  ("RT @SignaramaFC: Mulberry &amp; Lemay vie west 30 min ago. Can hardly believe it's actually 15 miles away!  #highparkfire URL ...",
#   3),
#  ("New game... Drink everytime you see a Sydney Bushfire photo on your Instagram feed... GO!.. OK I'll call you and ambulance now :-( #nswfires",
#   3),
#  ('RT @abcnews: The UN says the NSW fires are an example of the doom the world may face without action on climate change. URL',
#   3),
#  ('RT @KyleClark: RT @northfortynews: High winds at #HighParkFire sent flames 300-400 feet in the air near the top of East White Pine Mtn h ...',
#   3),
#  ('RT @BBCWorld: Australia bush fires set to worsen URL', 3),
#  ('High Park Fire: Kansas &amp;amp; Nebraska National Guards Support Colorado URL via @youtube [Like it? URL ]',
#   6),
#  ('Colorado Spring wildfire URL', 3),
#  ('Pic: #CoFire: Helicopter drops water on #WaldoCanyonFire #Wildfire USAF Academy Colorado Springs, Colo. URL',
#   3),
#  ("RT @onweeronline: Prachtige foto's van de National Guard in strijd tegen #HighParkFire #wildfire #firefighting #NationalGuard #Colorado  ...",
#   3),
#  ("@BasedBieberLife Australia fire threat 'averted': Australian fire officials say the threat to the Blue Mountains west of Sy...  @deadmau5",
#   1),
#  ('RT @LogansLaundry: At a shoot right near Sydney fires!! There is ash embers flying into my eyes!!',
#   3),
#  ("RT @australian: Fears grow blazes will form 'mega-fire': NSW fire chiefs are growing increasingly worried major bushfires in t... URL",
#   1),
#  ('#news #update Raging Colorado wildfire prompts FBI investigation - uReport: Colorado wildfire:  URL #follow',
#   3),
#  ('Firefighters search door-to-door for bodies in Colorado wildfire - Fox News: ABC NewsFirefighters search door-to... URL',
#   0),
#  ('#Sydney #fire please be over right now!! URL', 3),
#  ('RT @phochemrd: @msnbc there is a firestorm in Colorado  springs. #waldocanyonfire are your covering this? @CNN is still several hours be ...',
#   3),
#  ('RT @convectivetweet: Massive Wildfire near Colorado Springs. URL', 3),
#  ('Most destructive ever Colorado wildfire burns 181 homes - U.S. News URL #COLORADOWILDFIRES',
#   4),
#  ('RT @EmMastronardi: If you want to put the Lithgow fire in perspective, here is the size outlaid on a map of Sydney. #nswfires URL',
#   3),
#  ("RT @JezFernandezABC: It's just terrific seeing Auslan translators as a normal component of emergency mgmt procedures. Very smart. #nswfires.",
#   3),
#  ('RT @Denver_Broncos: #Broncos FB @Chrisgronkowski poses with a firefighter in Colorado Springs URL',
#   3),
#  ('RT @newscomauHQ: FIRE UPDATE: Families told to be ready to run as a massive 300km wall of fire sweeps through Blue Mtns. #nswfires | URL',
#   1),
#  ('RT @katelynburkhart: praying for the people, animals and entire communities affected by this #highparkfire. truly unreal.',
#   5),
#  ('State Mine: Photo from Mountain Lagoon Rd taken by Hawkesbury Gazette URL #nswfires #NSWRFS',
#   3),
#  ("Sitting here inhaling the #nswbushfires smoke. Can't imagine what ppl are going through. Buy an ad this week &amp; we'll donate to the victims.",
#   6),
#  ('YOU GUYS COLORADO SPRINGS IS TRENDING. prayers going out to the fire and all the girls i know living there.&lt;33',
#   5),
#  ('RT @NSWRFS: State Mine Fire: Fire has been downgraded to Watch &amp; Act #NSWRFS #nswfires',
#   1),
#  ('President Obama to tour #WaldoCanyonfire Friday URL via @denverpost #cofire #potus',
#   3),
#  ('Flames Encroach on Colorado Springs: Some of our viewers in Colorado Springs sent us their pictures of the fire ... URL',
#   0),
#  ('#Wildfire @ABC: Record Colorado Wildfire to Be Probed as Possible Arson URL',
#   3),
#  ('RT @9NEWS: BREAKING: new #COFire near Platteville, Weld Co CR32 &amp; CR35, there are evacuations PIC from Allyson Kulinski  URL ...',
#   0),
#  ("RT @Magdalena_Roze: This ISN'T rain on SYDNEY RADAR! Its a massive smoke plume from LITHGO FIRES travelling to coast by NW winds! #fires ht…",
#   3),
#  ("RT @TheEllenShow: Australia's 1 of the most beautiful places I've ever been to. Images of the fires are heartbreaking. Sending all my love …",
#   5),
#  ('RT @StyleEngine: Colorado Springs is burning, this gives you an idea of how bad the wild fire is... URL',
#   3),
#  ("Visits home allowed in areas burned by Colorado fires: People who fled the most destructive fire in Colorado's h... URL",
#   3),
#  ('RT @newscomauHQ: Investigations by NSW RFS fire investigators have determined the State Mine Fire... was started as a result of live ordna…',
#   3),
#  ('Thousands evacuated as Colorado wildfire nears URL', 0),
#  ('Ciggie butt may have started Sydney fire:      A cigarette butt is suspected of causing a grass fire at Sydney... URL',
#   3),
#  ('Colorado wildfire: Last Chance, residents stand tall after huge wildfire URL',
#   0),
#  ('Colorado wildfire forces 11,000 people to leave their homes \\\\ Guardian \\\\ URL',
#   0),
#  ("@chipmaclasco you're a better man than me. I hope Tim Thomas loses everything in the Colorado wild fires #ShouldveStayedInBoston",
#   3),
#  ('To all the Emergency crews in Colorado Springs. Be Brave and Godspeed! It is hell there right now. #firebrea URL',
#   5),
#  ('My thoughts and prayers are with the People and the Fire Fighters in Sydney...',
#   5),
#  ('RT @NationalPrayer: Heavenly Father, please be with the men and women fighting the #WaldoCanyonFire in the Colorado Springs area. Please ...',
#   5),
#  ('1 dead as Colorado fire destroys over 300 homes- uReport: Colorado wildfire URL #IHateTimWaterman',
#   0),
#  ('“@EmmaK46: Thinking of everyone helping to fight fires in Australia. Every day heros... 😢 URL #amazing #heros 🐨',
#   5),
#  ('Flick on TEN now RT @DaniIsdale: @SouthwoodEllie coming back live with update before the end of the show @TenLateNews #SydneyFires',
#   2),
#  ('346 homes destroyed in Colorado and 1 person found dead..my thoughts and prays are with the people of Colorado Springs during this time!!!',
#   5),
#  ("#Climate change and fires in Australia: why it won't be a smooth ride URL #nswfires",
#   3),
#  ("the #wildfires in Colorado are out of control! They are across the highway from my friend's apartment... URL",
#   0),
#  ('Colorado fire displaces hundreds; 1 person missing: Firefighters in Colorado and New Mexico are battling wind-fu... URL',
#   0),
#  ('RT @9NewsSyd: UPDATE: Watch &amp; Act alerts in place for #MtVictoria &amp; #Balmoral in Southern Highlands. @thetodayshow #nswfires URL',
#   1),
#  ('RT @larryemdur: Dear pathetic arseholes  looting houses in NSW fire zones .. You are disgusting pieces of shit !!!!',
#   5),
#  ('RT @9NEWS: #HIGHPARKFIRE now 45% containment, has burned 55,050 acres.  #9NEWS',
#   4),
#  ('RT @FireBlogger: Peregrin/Blodgett neighborhood Colorado Springs, no struct. protection. Not enough resources on scene #WaldoFire URL ...',
#   3),
#  ('RT @NHLPA: RT @ryanobyrne84: My thoughts are with everyone in Colorado and hoping the fires come to an end. #PrayForColorado',
#   5),
#  ("@SixlitreHSV tomorrow's conditions predict the worst in nsw history for these fires and there's nothing we can do to help #frustrating",
#   5),
#  ('Hey fam. Please pray for the residents of Colorado. With the winds, the fires are spreading rapidly. We are praying for you, Colorado!!!!',
#   5),
#  ('RT @NSWRFS: A picture tells 1000 words: Photos from the fire front and/or smoke plumes help us fight the fires email photos@rfs.nsw.gov.au …',
#   0),
#  ('Sky News - Colorado Wildfires: Blaze Claims First Life URL', 0),
#  ('Thanks for the RTs @mayread3 Maria, appreciate your support. Needs ongoing. #HighParkFire #smday URL',
#   5),
#  ('Large wildfire in northern Colorado prompts evacuations - Fox News: CBS NewsLarge wildfire in northern Colorado ... URL',
#   1),
#  ("RT @nprnews: Good News: 'Great Progress' Reported In Fighting Colorado Springs Fire URL",
#   3),
#  ('Colorado wildfires their worst in a decade URL', 3),
#  ('Thoughts going out to everyone affected by #nswfires', 5),
#  ('RT @NSWRFS: Likely to be heavy smoke across Sydney and much of the state Dont call 000 just for smoke only for unattended fires   URL',
#   1),
#  ('RT+@KCCINews:   #Australia bush #fires blaze in New South Wales URL', 3),
#  ('RT @fosterthepeople: “@fosterthefuture: fans helped us raise $15,830 for the Colorado Wildfire Relief Fund last night at Red Rocks. Spee ...',
#   6),
#  ('Colorado, New Mexico forest fire crews gain ground: (Reuters) - Fire crews battling flames roaring through natio... URL',
#   3),
#  ('“It’s ugly,” he said.  #HighParkFire #WaldoCanyonFire #COfire URL', 3),
#  ('Great interview, @riaglo!!! How Social Media Is Helping Colorado Wildfire Relief  URL via @mashable #COwx',
#   3),
#  ('RT @NSWRFS: Watch &amp; Act - Linksview Rd, Springwood Four local schools closed tomorrow URL #nswfires #nswrfs',
#   4),
#  ('#HighParkFire has burned about 73 square miles. Washington, DC measures 68 square miles. NASA photo t.co',
#   4),
#  ('Sydney fires will be known as the #greenoctoberfires thanks to @AdamBandt and fundamentalist party. #pmlive',
#   3),
#  ("RT @truuebluu: Don't forget our mates in the bushfires. #NSWfires URL", 5),
#  ('Praying hard. RT@DenverWestword: High Park fire update: 83K-plus acres, 248 homes confirmed destroyed  #highparkfire URL',
#   4),
#  ('RT @cnnbrk: Colorado governor lifts statewide fire ban. URL', 3),
#  ('RT @nswdpi: #nswfires: horses can be taken directly to #Penrith Paceway or the #Hawkesbury Showground @702sydney @NSWRFS',
#   1),
#  ('RT @dailytelegraph: Follow @NSWRFS - they are live tweeting all information they have immediately. @nswfires #bushfires #sydneyfires Blue M…',
#   1),
#  ('RT @rpy: ABC 702 reporting lit embers are falling on the water at Bondi #nswfires',
#   1),
#  ('RT @TmCentralCoast: “@NSWRFS: Important information about donations URL  #nswfires”',
#   6),
#  ('RT @AllianzStadium: DONATE YOUR SPARE CHANGE to the @SALVOS. Collection buckets located at entry gates tonight #SydneyDerby #sydneyfires #l…',
#   6),
#  ('RT @nswpolice: Fires, floods and park closures: See latest updates and alerts for national parks across NSW - URL',
#   4),
#  ('RT @DenverChannel: @Bri_Smith91 Sadly rain, well the lightning that came with it, started the Boulder fire yesterday.',
#   3),
#  ("Colorado fire claims first victim, ranks as state's most destructive: COLORADO SPRINGS, Colo. (Reuters) - A fier... URL",
#   0),
#  ('Colorado to double wildfire crews: Officials plan to more than double the amount of fire engines battling the ra... URL',
#   3),
#  ('#Australia #Wildfires: Nearly 100 Fires Rage Across New South Wales URL  #climate',
#   1),
#  ('My thoughts &amp; prayers go out to the victims and lost of loved ones to the wildfires in colorado. i wanna do a fundraiser.',
#   5),
#  ('RT @VaSarver: Yall complaining about no power and ac and the people in Colorado losing their HOMES and LIVES to fires. #bethankful',
#   5),
#  ('RT @dailycamera: Dispatchers: Heavy air tanker now en route to #BisonFire  west of #boulder',
#   6),
#  ('@kumitaguchi if you could use #nswfires that would be great', 3),
#  ('RT @BBCWorld: Video: Aerial views show extent of #nswfires, amid fears three blazes could merge URL',
#   0),
#  ('This is crazy #highparkfire URL', 3),
#  ('RT @Ai_Live: #Bushfire information for those who are #Deaf or hard of hearing. URL #nswbushfires',
#   3),
#  ('Lithgow bushfires #nswfires URL', 3),
#  ("RT @geoffstults: This is the Waldo Canyon fire in Colorado Springs and surrounding areas. Where my family lives. It's insane. URL ...",
#   3),
#  ('Record hot year causes fire emergency in Australia: The hottest 12 months on record in Australia have resulted... URL',
#   3),
#  ('Colorado wildfire hops road: Firefighters Thursday made progress against a massive wildfire 15 miles west of For... URL',
#   3),
#  ('@9NewsAdel feeling for the people of NSW. I have friends who have lost their home in this bush fires.',
#   5),
#  ("Here's a pic of Colorado and the fires from space. URL", 3),
#  ('RFS Commissioner says he still has concerns for #Springwood blaze  #nswfires',
#   1),
#  ('“@smh: A blood red sky over Tom Uglys Bridge in south Sydney. Photo: Chris Lane. #nswfires URL - RT - Amazing!',
#   3),
#  ('RT @LarimerCounty: Map of #HighParkFire as of 00:20 this morning. URL', 3),
#  ("RT @A_DarlingMP: Alex Salmond wants us to leave the Union. What assurances can he give that we won't end up on fire like Australia? URL",
#   2),
#  ('Great one here: Colorado wildfire roars to 73 square miles - Fox News  [a link in my bio]',
#   3),
#  ('Colorado fires sweep social media sites as readers look for info - Denver Post URL',
#   3),
#  ('RT @adam_wilkinson: Sydney fire 300km wide. Worst fire conditions in 40yrs. Katoomba preparing to evacuate &amp; state of emergency declared. S…',
#   1),
#  ("RT @mashable: Mashable's @zoebfox takes a look at how social media is helping Colorado wildfire relief URL",
#   3),
#  ('Sun through the smoke. #nofilter #sydneyfires URL', 3),
#  ('RT @cnni: 32,000 evaculated from Colorado wildfires URL', 0),
#  ("RT @p_hannam: Is this a sign that Abbott government will follow O'Farrell and outsource #climate science? URL #nswfires …",
#   3),
#  ('RT @weirdaustralia: Last October near Blackheath in the Blue Mountains #nswfires URL',
#   1),
#  ("We've reached the point of our trip to Colorado that we should be able to see mountains but because of the wildfires all we see is a haze.",
#   0),
#  ("Colorado fire 'smacks you in the face' - Neighborhoods in Colorado Springs, Colorado, are evacuated as the Waldo Can... URL",
#   0),
#  ('Aftermath of a Forest Fire URL via @wordpressdotcom -- 16 #photos #wildfire #environment',
#   3),
#  ('Where the fuck is @TonyAbbottMHR &amp; @GregHuntMP today to stand among these burnt homes &amp; spout climate denial bullshit. #nswfires',
#   3),
#  ('RT @AnthonyClarkAU: Incredibly proud of the #NSWRFS public info team over the last few days. In the age of technology and immediate info, t…',
#   3),
#  ('RT @cnnbrk: Officials: At least 57 bush fires rage in Australia; state of emergency declared URL',
#   1),
#  ("#nswfires People queuing for over an hour at Blaxland tip. C'mon Blue Mtns council open up the tip!",
#   0),
#  ('Hang in there New South Wales. The rest of Australia is thinking of you. Stay safe. #nswbushfires',
#   5),
#  ("Key points from this morning's 7am briefing at NSW Rural Fire Service HQ - * 56 bush and grass fires, 12... URL",
#   3),
#  ('US: All three network evening newscasts leading tonight with the rampage of that #wildfire in #Colorado',
#   3),
#  ('Sydney CBD skyline, shrouded in smoke, blue skies reflected in the glass of the buildings. #nswfires #bushfires URL',
#   3),
#  ('RT @smh: Sydney Water warns that water pressure may be low in some areas due to extremely heavy demand for fire fighting. URL',
#   1),
#  ('RT @NSWRFS: #NSWRFS crews are responding to a fire reported in the Salt Ash area (Port Stephens). #nswfires',
#   3),
#  ('RT @NSWRFS: Status of evacuation centres: URL #NSWRFS #nswfires', 1),
#  ('RT @Lisa_Wilkinson: To all the men &amp; women out there today fighting the good fight in the worsening #nswbushfires thank you. Your bravery &amp;…',
#   5),
#  ('RT @diversionary: Another bushfire sunset in Sydney… thoughts go out to everyone affected by or fighting the fires',
#   5),
#  ('RT @denverpost: #HighParkFire, at 14,000 acres (22 sq. miles), is roughly the same size as the city of #Boulder (24 sq. miles): URL ...',
#   3),
#  ('#bushfires #nswfires #sydney URL', 2),
#  ('In Focus - Colorado Wildfires: The Aftermath - The Atlantic URL', 3),
#  ('RT @smh: The entire Blue Mountains area as well as Penrith and Richmond are in danger of burning over the next few days. #nswfires',
#   1),
#  ('Hoping this is over soon for all concerned. #nswfires', 5),
#  ('RT @HomefrontHugs: We have hundreds of military families &amp; veterans evacuating from the fires now in Colorado -We needed a wake up c ...',
#   0),
#  ("RT @emilyrsutton: Praying for the people of Colorado Springs dealing with the worst wildfire in a decade. Here's a live stream: URL ...",
#   5),
#  ('RT @Jane_Dyson: Smoke covers Sydney and turns day into night. Picture: Jane Dyson  #smoke #bushfire #fire #sydney @… URL',
#   3),
#  ('#NSWFIRES  NE of Mount Coramba, Type: Bush fire, Status: Out of Control, Size: 1 ha, Map: URL URL',
#   1),
#  ('@electravision I am waiting for the carbon tax bill for the bush fires in nsw. Who will they send it to?',
#   3),
#  ('RT @Channel9: #NSWFires UPDATE: A big concern for the area of Wilton. An Emergency warning has been issued residents should seek shelter. @…',
#   1),
#  ('Fires could head toward Sydney URL #news', 1),
#  ('#newbedon 6/26/2012 2:47:53 PM Colorado fire near Pikes Peak forces 11,000 from homes URL',
#   0),
#  ('BREAKING: 11yo boy now charged with lighting fires: URL #NSWfires #sydneyfires #liveblog',
#   3),
#  ("2.05 Live Media briefing available at URL or download the 'livestream' app and follow nswrfs #nswrfs #nswfires",
#   3),
#  ('For all in Sydney and most of Illawarra “@Nyx2701: Sydney Water statement: #BlueMountains #bushfires URL #NSWFires”',
#   1),
#  ('@hash5wag: so sad #damn URL Colorado skies: wildfire style.', 5),
#  ('RT @9NewsSyd: UPDATE: Smoke from fire around #Dudley &amp; #Redhead could affect surrounding suburbs #nswfires URL',
#   1),
#  ('RT @News1130radio: BC Wildfire Management says the smoky haze will last until at least Friday. Smoke is coming not just from Colorado, b ...',
#   3),
#  ("RT @ABCCentralWest: 'Worst-case scenario': Blue Mountains blazes threaten to combine into mega-fire URL #nswfires",
#   3),
#  ('Riding inside again. Wish all this rain would clear out and put the fires out in NSW ! URL',
#   3),
#  ("🙏pray for the victims of the Colorado fires🔥 It's getting bad out there 😔",
#   5),
#  ("RT @PatrickSandusky: This is colorado springs right now. Look at this photo and be shocked.  Its f'ing armageddon here URL",
#   0),
#  ('Colorado wildfire worsens, forcing 7,000 more from homes - Terra USA  URL via @TerraNoticiasUS',
#   0),
#  ('RT @RobertOvadia: RIP chief pilot David Black from NSW Central West, killed fighting the #NSWFires this morning. A good man. URL',
#   0),
#  ('RT @workmanalice: Amazing photo from a friend in Katoomba on the road to Blackheath. #nswfires URL',
#   3),
#  ('RT @MelindaHealy: Newcastle airport closed due to smoke from bushfire at williamtown #fires #nsw #newcastleairport URL',
#   4),
#  ('RT @DamonAM: My opinion of the @NSWRFS neatly summarised into a comic. #nswfires URL',
#   3),
#  ('Lord God, I pray that you bring a cool refreshing rain upon Colorado Springs, in the name of Jesus Christ, amen.',
#   5),
#  ('RT @EmergencyAUS: NSW - For scale, latest #Lithgow #bushfire perimeter overlaid across #Sydney. #nswfires URL URL',
#   1),
#  ('Colorado Springs is my town also, PLEASE if ya can help  URL help with your donations',
#   6),
#  ('RT @SebHenbest: To not talk about #climate when fires a raging through NSW in Oct! is like not talking about guns after a US massacre URL',
#   3),
#  ('says URL Hundreds of homes destroyed in Colorado Springs fire URL', 4),
#  ("VIDEO: Colorado wildfire 'moving fast' URL", 3),
#  ('RT @SkyNewsAust: . @NSWRFS Commissioner says 95 fires are burning across NSW, 30 of which are uncontained.',
#   3),
#  ('#newsupdate Weather fear as Australia fires burn: More than 3,000 firefighters in Austral... URL #bbc #news #bbcupdat',
#   1),
#  ('$50K Reward Offered For Info On Waldo Canyon Fire Vandals URL #WaldoCanyonFire #Colorado',
#   3),
#  ('EMERGENCY WARNING - #rfsnsw maintain emergency warning for Bell, Dargan, Clarence &amp; Bilpin URL #nswfires',
#   1),
#  ('RT @kevinltorres: 20,085 homes in Colorado Springs are threatened by the wildfire, according to CSFD.',
#   4),
#  ('RT @KyleLSaunders: Just some perspective: 14000 acres = 21.87500 sq mi #highparkfire; @LarimerSheriff notes still 0% containment--so sco ...',
#   4),
#  ('RT @NSWRFS: Media release - Total fire bans until further notice - URL #NSWRFS #nswfires',
#   1),
#  ('Live feed for #WaldonCanyonFire #Wildfire #CO #COFire URL', 3),
#  ('Colorado wildfires URL', 3),
#  ("RT @ABCemergency: If you're in #Sydney get #bushfire #nswfires updates on @702sydney and @NSWRFS and listen to our live stream: URL",
#   1),
#  ('Colorado wildfire smoke chokes Cheyenne, Wyo. – URL URL', 3),
#  ('RT @Channel9: #NSWFires UPDATE: 58 fires are still burning with 14 uncontained! For emergency information on the fires call 1800 679 737 #9…',
#   1),
#  ('Praying for Sydney, Australia concerning the bush fire situation. URL', 5),
#  ("Relief crew has arrived and we're now heading back to station in a coach. Long day. Good luck to night crew. #nswrfs",
#   6),
#  ('Colorado wildfire: Winds whip flames; 32,000 ordered to evacuate URL', 0),
#  ('RT @deshuis: Latest #NSWfires update from @geehall1 here: URL @nat_forrest',
#   1),
#  ("'Miracle' if NSW fires don't kill: premier via @Y7News URL URL", 3),
#  ("Here's a photo taken yesterday by @FireRescueNSW after the fire in Sydney's Olympic Aquatic Centre carpark URL",
#   3),
#  ('RT @acousteau: @nprnews Great coverage of why it matters to us that the #Colorado continue to flow... URL',
#   3),
#  ('RT @cnnbrk: #Colorado firefighters facing more wind, heat. URL', 0),
#  ('The High Park fire west of Fort Collins, #CO has consumed 36,930 acres so far, is 0% contained and continues to grow. #NWS #cowx #cofire',
#   4),
#  ('Colorado fire news: URL via @msnbc', 3),
#  ('#HighParkFire trying to get more of all resources.. air, ground crews, military assistance.. competing for fire resources due to other fires',
#   3),
#  ('Colorado High Park Fire: Potential Looters Pose New Threat - ABC News: ABC NewsColorado High Park Fire: Potentia... URL',
#   3),
#  ("@NSWRFS: Media release from CASA warning people to keep 'drones' off fire grounds URL #nswfires @DozerTweet",
#   1),
#  ('Our joint venture Western Lands &amp; Communities @sonoraninst has produced guide to managing the impacts of #wildfire  URL',
#   1),
#  ('RT @WSJ: A Colorado fire forced 32,000 residents to evacuate. It doubled in size overnight to 24+ square miles. Photos: URL',
#   0),
#  ('RT @LMBeautyShines: Colorado Springs is FINALLY trending.  This fire is the #1 priority in the US!!! :( Please pray for our community!',
#   5),
#  ('RT @ryanmunyan: “@bretstrelow: Colorado Springs fire approaching Air Force football stadium. This pic, just wow URL un ...',
#   1),
#  ('At least 40 homes destroyed in #SydneyFires #Australia', 4),
#  ('About 80 bush fires all around NSW today.. This sky is starting to look a little creepy. URL',
#   0),
#  ("RT @MarkDiStef: Defence Dept's been investigating after revelations it started NSW's biggest fire. Ch7 says Defence now admitted to @NSWR…",
#   1),
#  ('RT @LarimerSheriff: #HighParkFire evacuation orders issued for Pingree Park area.  25 notifications sent URL',
#   1),
#  ('RT @egorski: Bizarre to hear a Colorado Springs TV reporter interviewed on the BBC tonight #WaldoCanyonFire',
#   3),
#  ('Why does Colorado have to have a fire right now! #sad', 3),
#  ("Why isn't our superman PM fighting the NSW fires? He can for his claim volunteering as well. #auspol",
#   6),
#  ('Helicopter collecting water for multiple cars on fire at Sydney Olympic ...: URL via @youtube @ChrisBath7',
#   4),
#  ('“@cnnbrk: Officials: At least 57 bush fires rage in Australia; state of emergency declared URL 😥',
#   1),
#  ('Plane fighting Australia fires crashes as cooler weather eases threat URL via @reuters',
#   1),
#  ('High Park Fire 2012: Colorado Blaze Burns Record Number Of Homes: DENVER -- Additional crews were arriving Satur... URL',
#   4),
#  ("#fnre #nswbushfires NSW residents download 'Fires Near Me NSW' App from iTunes using link URL URL",
#   3),
#  ('#highparkfire from Loveland  URL', 3),
#  ('Sydney skyline from the fires. #nswfires #fires #nswrrfs #Sydneyfires #bushfires #Sydney URL',
#   4),
#  ('RT @gannett: Terrific panorama shot of the #HighParkFire from @MattStephens with the @coloradoan.  URL',
#   3),
#  ("RT @ABCNews24: Fitzsimmons: I sincerely plead with people don't become complacent #nswfires URL #NSWRFS",
#   3),
#  ('RT @NSWRFS: Ash and smoke from Hall Rd #Balmoral fire visible in the Illawarra. #NSWRFS. #nswfires',
#   3),
#  ('RT @Optus: With Optus? Text DONATE to 19 Relief (19 735433) to donate $5. All funds will go to @RedCrossAU work with #NSWbushfires &amp; other …',
#   6),
#  ('RT @amworldtodaypm: Coming up on TWT: One dead &amp; more than 100 homes lost in what has been called the worst #bushfire day in #NSW in more t…',
#   0),
#  ('RT @EdJReporter: Fears #nswfires could join up and form a mega-blaze. Via @nswfire: @DeptDefence closely monitoring #nswfires crisis URL',
#   3),
#  ('RT @AP: Wildfire near Colorado Springs quickly becoming dangerous threat as thousands of residents evacuate homes: URL -JM',
#   0),
#  ('Colorado State University classes disrupted by High Park Fire  URL', 3),
#  ('Raging US wildfire continues to ravage Colorado | List Submission: URL', 3),
#  ('RT @HuffingtonPost: Photo gallery of the multiple devastating wildfires burning across Colorado URL',
#   3),
#  ('RT @tracysolomon: PHOTOS: View aerial images of the #WaldoCanyonFire in Colorado Springs: URL #cofire',
#   3),
#  ('RT @smh: Fires burn in #Lithgow. Photo by the @lithgowmercury. #nswfires URL',
#   3),
#  ('Coalition misses the point. Yes fires are way of life in Oz. This severe SO EARLY IN THE SEASON is the problem. #auspol #nswfires #toosoon',
#   3),
#  ('NSW Rural Fire Service @NSWRFS spokesperson Joel Kursaw just told @RNDrive the fire season may be longer now. #nswfires #auspol #climate',
#   1),
#  ('Four-year-old believed to have caused house fire on NSW mid-north coast - The Age URL',
#   0),
#  ('How to assist Colorado wildfire victims, how to donate and help - The Denver Post URL',
#   6),
#  ('RT @Denver_Broncos: Broncos pledge $50,000 to Colorado wildfire relief efforts URL',
#   6),
#  ('Colorado wildfire: Winds at Waldo Canyon Fire concern officials - San Jose Mercury News URL',
#   3),
#  ("Def don't miss the bushfires. Hope everyone back home is safe #nswfires",
#   5),
#  ('RT @SebHenbest: Australia has always experienced bushfires, but #climate change is increasing the PROBABILITY of extreme fire days &gt; URL',
#   1),
#  ('Nina (aka: The Spare) outside our house in Parramatta. These #SydneyFires are amazing URL',
#   3),
#  ('57 fires scorch eastern Australia: At least 57 bush fires are raging in eastern Australia, including 14 that a... URL',
#   3),
#  ('colorado fire: ... URL', 3),
#  ('RT @TenNewsSydney: #NSWFires #SydneyFires Winmalee press conference - authorities try to take advantage of favourable weather conditions to…',
#   3),
#  ('Mayor: Colorado Springs Fire Destroys 346 Homes: Mayor: Colorado Springs fire destroys 346 homes',
#   4),
#  ("RT @darinsullivan09: #FIRE PHOTO: most days #FRNSW fire stations shut in NSW under O'Farrell fire budget cuts. #NSWPOL #cutscostlives URL",
#   1),
#  ('@GarcelleB Pls spare a thought/prayer for the brave men and women on the front line of the #nswfires #asbadasitgets #prayforrain',
#   5),
#  ('@Kajahh @cmpunk but I think they said they were going to have double raw and SD since SD was canceled in Colorado because of recent fires.',
#   3),
#  ('RT @Nyx2701: “@9NewsSyd: #Springwood fire now threatening St Columba’s School. #nswfires URL #BlueMountains #BushFires',
#   1),
#  ('CNN: Colorado wildfire hops road URL', 3),
#  ('RT @astropixie: wow!  this isnt rain on the radar, its a huge smoke plume covering sydney from fires in lithgow! URL',
#   4),
#  ('Wildfire continues to threaten Colorado Springs neighborhoods and ministries URL',
#   3),
#  ('RT @PeterDoherty7: The Queenslanders are on their way to help New South Wales #nswfires @7NewsBrisbane URL',
#   5),
#  ("@TripleMSydney thank you for the excellent coverage of the #nswfires this along with great music is why i listen to the M's :-)",
#   5),
#  ('Colorado Sees Record Fire Damage URL', 3),
#  ('Sending love &amp; safe thoughts to my fellow #novacastrians as these #nswfires burn #keepsafe.',
#   5),
#  ('@bigshow81 was good mart, how was yours? Mark Bosnich was on talk sport he reckons u can smell the bush fires in Sydney ?',
#   3),
#  ('RT @workmanalice: Amazing photo from a friend in Katoomba on the road to Blackheath. #nswfires URL',
#   3),
#  ('RT @fema: (June 27) Please share: how to help those affected by the #WaldoCanyonFire #FlagstaffFire #HighParkFire URL',
#   6),
#  ("Another game pitching and it's raining I thought I was getting away from the rain!!!!!! Your welcome Colorado I'm here to help your fires",
#   3),
# ...
#  ('RT @BBC_WHYS: Live talking to #firefighters and residents around #NSWfires Listen  URL   everyone indebted to the fire …',
#   5),
#  ('Thousands take refuge from Colorado wildfires URL', 0),
#  ('57 fires scorch eastern Australia: At least 57 bush fires are raging in eastern Australia, including 14 that a... URL',
#   1),
#  ('RT @nswfire: #nswfires #agchatoz  Animal welfare relief services: Department of Primary Industries 1800 808 095 Website URL',
#   3),
#  ('Colorado wildfire: Tankers resume fighting 52000-acre High Park fire - Denver Post: Fox 31 KDVR.comColorado wild... URL',
#   3),
#  ('A Total Fire Ban has been declared for the Greater Sydney Region on Sunday 13th October 2013 between 12:00am -... URL',
#   1),
#  ('Jesus...half this state is on fire and its 102° right now.  #summerfun colorado style',
#   3),
#  ('RT @kmitchellDP: Colorado wildfire: some residents defy evacuation order for #highparkfire. URL',
#   0),
#  ('A picture someone took of Colorado Springs looking downright apocalyptic   URL',
#   3),
#  ('RT @tigervixxxen: Not sure if anyone has heard but now 14 wildfires in Colorado. Many homes and 100,000+ acres already lost. Prayers please.',
#   3),
#  ('Take care with all this Bushfire smoke around: some helpful tips from Asthma Australia Foundation. #ausunions #fires URL',
#   5),
#  ('@nswrfs thanks @QantasAirways . Their staff in groups helping to take our interstate colleagues home today and tomorrow #nswfires',
#   6),
#  ('Colorado. Soon to feature plagues of locusts.: First, the big fire came.   Then, the firefighters arrived to fig... URL',
#   3),
#  ('Watch live:  Colorado Wildfire Aerials URL', 3),
#  ('They need us as well #nswfires URL', 6),
#  ('RT @geehall1: RT @Prussan: Charred material found at UNSW. #nswfires URL',
#   3),
#  ('RT @ColoradoStateU: Meet Ellie, a donkey who lead another donkey and 4 horses to safety before evacuation from #HighParkFire. URL ...',
#   3),
#  ('RT @smh: Do not light fires in the open: RFS warns as #Sydney braces for strong winds and hot weather on Sunday. URL',
#   1),
#  ('Great info on how to help #people and #pets URL via @ColoradoStateU #HighParkFire #cofire',
#   3),
#  ('Obama to visit Colo. to review fire damage: President Obama will fly to Colorado Springs on Friday to review the... URL',
#   3),
#  ('RT @DenvNuggetsnews: LIVE VIDEO: Waldo Canyon Fire in Colorado Springs - URL URL',
#   3),
#  ('RT @illwah: Love your prayers in Aust for the NSW fires. Over 200 homes lost now &amp; 80 different fires burning. Pls pray for our fire fighte…',
#   5),
#  ("Amazing images from the October 2013 New South Wales' bushfires URL #nswfires",
#   3),
#  ('Prayers for the safety and well being of all as wildfires close in on Colorado Springs.',
#   5),
#  ('This map gives you a sense of how big the fires are in the Blue Mountains region. #nswfires URL',
#   3),
#  ('RT @instagram: Frightening photo of the Colorado #wildfire by @dredayy66: URL Please stay safe!',
#   3),
#  ("RT @thetodayshow: Here's a NASA satellite photo showing the #nswfires #today9 URL",
#   3),
#  ('Amazing time lapse footage of Colorado Springs fire. URL', 3),
#  ('Heading home from Denver this evening around 7pm, Colorado Springs is on fire URL',
#   0),
#  ('RT @702sydney: A couple of kilometres of ember activity being reported at #wilton : @NSWRFS #nswfires',
#   3),
#  ('Is it counter-productive to link NSW bush fires with climate change when the majority are caused by humans? #ClimateChange',
#   3),
#  ('This is what the sun looks like in colorado with all the smoke from the fire! #pinksun  URL',
#   3),
#  ('Colorado Springs POLICE are closing PALMER PARK as a PRECAUTION ONLY!!!!! #WaldoCanyonFire',
#   1),
#  ('RT @robrfs: Image of fire at Port Stephens burning very aggressively #nswfires URL',
#   3),
#  ('On-air shortly with Early Edition on @NewstalkZB - talking TeamNZ with Peter Lester, NSW bush fires plus Bill English is on the programme.',
#   3),
#  ('The fire has offically reach the city of Colorado Springs. Please be praying. URL',
#   5),
#  ('Western wildfires forcing evacuations: Firefighters in Colorado and New Mexico are battling wildfires that are m... URL',
#   3),
#  ('Hundreds of homes destroyed in Colorado Springs fire: URL via @msnbc...they need HELP!!!',
#   4),
#  ('RT @denverpost High Park fire competes with blazes across the state URL &gt; &gt; seems the whole state is on fire #HighParkFire',
#   3),
#  ('RT @robrfs: Fire up on Putty Road even on benign weather day #nswfires URL',
#   4),
#  ('RT @ReBourne_Again: Everyone please pray for our state of Colorado! There are 9 fires burning in our state! The most recent is The... h ...',
#   5),
#  ("Good morning - 6pm producer Duncan Shaw here with the morning news meeting.  We'll be covering the #cofire all day long.",
#   3),
#  ('We send this prayer to all those affected by the #Colorado fires.  URL', 5),
#  ("Crazy // RT @denverpostjoe: Today (Tuesday's) #cofire math: .187% of Colorado's on fire (194.9 sq. miles / 124,781 acres)",
#   4),
#  ("Australia's hottest 12 months on record have produced huge bush fires very early but their PM tries to deny it is due to Climate change!",
#   3),
#  ('RT @Colorado: Please RT: Text the word FIRE to 80000 to donate $10 to the Colorado Fire Relief Fund 2012 @mgive',
#   6),
#  ('Is the Colorado Wildfire the Future Norm? URL', 3),
#  ('The skycrane working through the smoke at #faulconbridge Image l John Donegan URL',
#   4),
#  ("RT @BreakingNews: Evacuation order issued in Colorado's High Park Fire - @LarimerSheriff URL",
#   0),
#  ("RT @JustCindeh: HAHAHAHAHAHA!!!!!!! RT @word_34  Michelle Malkin's mouth is foaming so bad she could almost put out the Colorado wildfires.",
#   2),
#  ('Help Colorado Springs Military Communities Threatened by Fires - URL', 6),
#  ('RT @MmaGeneration: UFC Heavyweight Shane Carwin on the Colorado Fires + Getting Back to the Octagon URL @ShaneCarwin',
#   5),
#  ('RT @RebelWilson: Thinking of everyone in Western Sydney who are being affected by the bush fires x be safe x',
#   5),
#  ("The fire in Colorado might burn down the hospital I was born at )':", 4),
#  ('Please keep my family, as well as the other families that had to evacuate the Colorado Springs area due to forest fires, in your prayers',
#   5),
#  ('RT @BreakingNews: Colorado wildfire now over 50,000 acres, officials say; more than 1,300 personnel battling the blaze - @denverpost  ht ...',
#   3),
#  ('RT @ProFootballTalk: Broncos DE touched by Colorado wildfire tragedy URL',
#   5),
#  ('RT @KyleLSaunders: Whoops, wrong link: #HighParkFire threatens largest Buddhist temple in North America URL',
#   4),
#  ('RT @COEmergency: Want to donate to #HighParkFire families? Go to URL', 6),
#  ('@TenLateNews The bush fire smoke smothering La Perouse Sydney this afternoon . URL',
#   4),
#  ('Hope everyone in NSW is safe xx #bushfires #nswfires', 5),
#  ("RT @derindevine: There are a total of 95 fires burning across New South Wales, I can't even fathom that #nswfires",
#   3),
#  ('Wildfires in Colorado and New Mexico ravage thousands of acres of forest and cause massiv... URL + URL',
#   3),
#  ('RT @TheMindBlowing: A dog has risked its life to save a litter of newborn kittens from a house fire in Melbourne, Australia: URL',
#   0),
#  ("Even as fires burn out of control around NSW - O'Farrell Govt accused of cutting #climate change research! via @ABC URL",
#   3),
#  ('“@news_com_au: THE wildfire burning just west of Fort Collins, Colorado, has destroyed 181 homes, ... URL',
#   4),
#  ('RT @denverpost: LIVE: View photos shared on social media of the #WaldoCanyonFire: URL #CoFire',
#   3),
#  ('Photo: Live shot from the ABC helicopter of smoke over the #BlueMountains from the #MountVictoria fire #nswfires URL',
#   4),
#  ("RT @Idealaw: Firefighters are using Twitter to rapidly map + respond to NSW's bushfire crisis. URL #nswfires",
#   3),
#  ('These fires out in Colorado are crazy.', 3),
#  ('RT @louanndonovan: Photo taken by someone of wildfire in Colorado Springs. Shows #SalvationArmy there helping. #waldocanyonfire URL ...',
#   6),
#  ('RT @woolkebb 1m  Stop Tony Abbott fanning the flames of climate change. Sign now #nswfires URL …',
#   3),
#  ('Colorado wildfire now 50 percent contained URL', 3),
#  ("@LetMeBeYourLove you'l be fine love . hopefully , you wont be in Colorado Springs cus they got that wild fire down there .",
#   5),
#  ('Keep the tens of thousands affected by the Colorado Wildfires in your hearts and minds. URL #COfires #Colorado Springs',
#   5),
#  ("Explosives sparking blazes &amp; arsons sure doesn't sound like climate change to me. #nswfires #auspol",
#   3),
#  ("RT @GalacticWomanAu: Shouldn't the Prime Minister of the nation be making some kind of public statement about the fire emergency in NSW?",
#   3),
#  ('#OPENFOLLOW Weather fear as Australia fires burn: More than 3,000 firefighters in Australia ba... URL #TEAMFOLLOWBACK',
#   3),
#  ('@billmaher please RT - help Colorado Springs with the #WaldoCanyonFire URL we need all the help we can get right now!',
#   6),
#  ('RT @carolinelec: Premier @barryofarrell says NSW has a bush fire crisis.When will @TonyAbbottMHR realise we have a #climate crisis and keep…',
#   3),
#  ('RT @DarknessRadio: Lord please bring the driving rain to Colorado to stop the horror that is taking place there. End the fires &amp; sav ...',
#   5),
#  ('RT @abcnews: #breaking: Air Marshall Binskin apologises on behalf of Defence after confirmation live fire exercise linked to #nswfires',
#   3),
#  ('RT @702sydney: Needing info on school closures for today? Full list available here: URL #nswfires',
#   1),
#  ('Unbelievable community support in Colorado Springs! URL', 5),
#  ('15 Australia wildfires still burning out of control: Authorities warn high temps, strong winds likely to keep heightened fire danger ...',
#   1),
#  ('FEMA has authorized the use of federal funds to help with firefighting costs for the #HighParkFire. URL',
#   3),
#  ('See state of emergency declared in NSW because of bush fires - hope you are OK!',
#   1),
#  ('RT @thetodayshow: UPDATE: 64 fires burning, 24 uncontained. Dropped temperatures but strong winds. Authorities warn: #nswfires crisis is fa…',
#   1),
#  ('RT @coloradodaily: Latest on the #FlagstaffFire w/photo, video &amp; map: URL',
#   3),
#  ('RT @hillaryrosner: 32,000 people have been evacuated in Colorado Springs, and the NYT home page is still Nora Ephron. I find that upsetting.',
#   0),
#  ('RT @Jon_G3: Seeing 1/3 of Colorado on fire makes me wonder how certain political figures can argue cutting fire fighter numbers #COFire',
#   5),
#  ('#waldocanyon fire....Views from my parents neighborhood....they have evacuated. I did steal these photos fro URL',
#   0),
#  ('RT @9NEWS: Evacuations lifted in Flagstaff Fire near Boulder  #9NEWSHeadlines',
#   1),
#  ("Australia fires: Firefighters fought scores of bush fires blazing in Australia's New South Wales early Friday. URL",
#   6),
#  ('RT @benloiacono: Cigarette butts cause #bushfires. Please bin your butt! #hillsdistrict #SydneyHills #NSWRFS',
#   1),
#  ('#IFWT Colorado Wildfires Getting Worse - URL', 3),
#  ('Lord please watch over Your people over in Colorado who are havin a very difficult time with these wildfires. Please take care of em.',
#   5),
#  ('These colorado wildfires are no joke', 5),
#  ('Colorado wildfire worsens, forcing 7,000 more from homes: COLORADO SPRINGS (Reuters) - A monster Colorado wildfire raging near some o...',
#   0),
#  ("RT @TheEllenShow: Australia's 1 of the most beautiful places I've ever been to. Images of the fires are heartbreaking. Sending all my love …",
#   5),
#  ('Update l Police Arrests    NSW Police have arrested a second boy, aged 15 over the #Heatherbrae Fire.',
#   0),
#  ('@Sim_One76 Are any of the group near the fires Simmy? Is it just in one State..NSW?',
#   3),
#  ('RT @LiveTrafficNSW: LITHGOW TO BELL: #BellsLineOfRoad is OPEN again in both directions after being closed due to #nswfires earlier.',
#   4),
#  ('I really hope that someone did not deliberately start any of the fires going on here in Colorado, that would be just disgusting. Absolutely.',
#   5),
#  ('RT @UniversitySA: This is so, so true! Hats off to the men and women battling the blazes! #NSWfires ^BS URL',
#   5),
#  ('RT @climatecouncil: David Jones, Bureau of Meteorology, said climate change will see fire conditions worsen for much of Australia URL',
#   3),
#  ('Hoping the rain is falling in the right places #nswfires', 5),
#  ('Ack! A fire now in Boulder!', 3),
#  ('RT @TheDingoTracker: Thoughts are with all the people and animals fighting and fleeing fires in NSW @NSWRFS @OEHmedia @NPWSnorthern @BMWHI',
#   5),
#  ('#nswfires ALERT  Damaging winds around 60km/h with peak gusts of 90km/h forecast for #sydney Illawarra, Southern Tablelands, Snowy Mountains',
#   3),
#  ('RT @abcnews: The Hawkesbury Showground has become a makeshift animal sanctuary due to the bushfire threat. URL #nswfires',
#   4),
#  ('Help Colorado recover from the fires URL #PrayersForColorado #HelpColorado #PineRidgeFire #waldocanyonfire',
#   5),
#  ('KRDO has a live feed up with aerials from the Colorado Springs WILD FIRE   URL',
#   3),
#  ('390 #HighParkFire evacuees  told they can return home Wednesday URL', 0),
#  ('RT @NSWRFS: If you find an injured native animal, call WIRES 13000WIRES or DPI for livestock.  URL @WIRES_NSW #nswfires',
#   6),
#  ('Growing wildfire brings evacuations in Colorado Springs URL', 0),
#  ('#waldocanyonfire #waldofire sending as much positive thoughts as I can to C Springs. Love that land!',
#   5),
#  ('[LIVESTREAM] Waldo Caynon Fire Colorado USA URL URL', 3),
#  ('#LarimerCounty Colorado, #HighParkFire Map of fire: URL', 3),
#  ('Spreading the fire to 100 houses ashes Australia URL via @allvoices', 4),
#  ('India Large wildfire in N. Colorado prompts evacuations URL', 0),
#  ('RT @tmrounsaville: View of #highparkfire from #hughesstadium #csu the smoke was unreal on Sunday @coloradostateu URL',
#   3),
#  ('RT @BryceEngland15: Hazy day in #Canberra today due to #nswfires - worse on the coast though. Challenging flying in 2km visibility! URL',
#   2),
#  ("RT @GOPrincess: You know... These Colorado wildfires are on their way to becoming Obama's FEMA disaster, ala Katrina. Slow-moving silenc ...",
#   3),
#  ('RT @iowahawkblog: Wildfires rage in Colorado; EPA, Interior Dept promise to send emergency string quartet',
#   6),
#  ("RT @bromleyfalco: @KRQEMark Good work on the  #cofire updates Mark. I'm from Denver, been in NM about 9 months now...thx sadly we know fire",
#   0),
#  ('RT @ABCemergency: #nswfires: 2 x Emergency Warnings in place for fires near #Lithgow #Bilpin + Mount York Rd fire near #MountVictoria URL',
#   1),
#  ('#teamfollowback Australia bush fires set to worsen URL  #autofollow', 3),
#  ('It is doingsome raining #onthefarm!!!   LORD send of this to put out the fires in Colorado.  #Thrutheflames safety!!!   #BelovedofGOD',
#   5),
#  ('RT @BlueDuPage: Romney plan for #Colorado wildfires :  Fire  firefighters. Ignore climate change.  Take $$$ from Koch Brothers.  #Mitt20 ...',
#   3),
#  ('RT @NSWRFS: NSW Governor Marie Bashir has visited #NSWRFS HQ, passing on her thanks to the thousands of firefighters #nswfires URL',
#   5),
#  ("@702sydney: Fire crews are checking car fuel tanks after a grassfire spread to the carpark of Sydney's Olympic Aquatic Centre #TooClose",
#   4),
#  ('Waiting for the fire front - asset protection duty #nswbushfires URL', 0),
#  ('RT @LarimerSheriff: #HighParkFire Final Evening Update for 6-18-12.  Made some progress on containment! Check out the link. URL ...',
#   3),
#  ('Information on employment protections for NSW RFS members involved in the current fires URL #nswfires #NSWRFS',
#   1),
#  ("Fires spread to Colorado tourist centers: Wildfires moved in on some of Colorado's most popular summer tourist d... URL",
#   3),
#  ('Fire warning issued for NSW south coast URL', 1),
#  ('RT @TammyBarber: Lord, protect those in the path of the fires in Colorado. Please, send your Divine extinguisher for those fires!',
#   5),
#  ('Waldo Canyon fire near Colorado Springs reaches 98 percent containment URL via @denverpost',
#   3),
#  ('RT @DearNinax3: Crazy fires in Colorado 🗻🔥 URL', 3),
#  ("'We have the ability to name and shame' @BarryOFarrell says of people trying to take financial advantage of #nswfires URL",
#   2),
#  ...]
